# %% [markdown]
# ### Plotly

# %%
import plotly.graph_objects as go
import plotly.io as pio

# Define the updated HorizonAnalytics template
HorizonAnalytics = go.layout.Template(
    layout=go.Layout(
        paper_bgcolor='#0d1b2a',  # Background color
        plot_bgcolor='#0d1b2a',  # Background color
        height=800,
        width=800 * 1.618,
        xaxis=dict(
            anchor='y',
            showgrid=True,
            gridcolor='rgba(255, 255, 255, 0.2)',  # Softer grid lines for contrast
            tickfont=dict(
                size=36,  # Consistent with other elements
                family='Montserrat, sans-serif',
                color='#ffffff',
                weight="bold"
            ),
            title=dict(
                text='',
                font=dict(
                    size=48,  # Increase to match other elements
                    family='Montserrat, sans-serif',
                    color='#ffffff',
                    weight="bold"
                )
            ),
            linecolor='#ffffff',  # White axis lines for contrast
            linewidth=2
        ),
        yaxis=dict(
            anchor='x',
            showgrid=True,
            gridcolor='rgba(255, 255, 255, 0.2)',  # Softer grid lines
            tickfont=dict(
                size=36,  # Consistent with x-axis
                family='Montserrat, sans-serif',
                color='#ffffff',
                weight="bold"
            ),
            title=dict(
                text='',
                font=dict(
                    size=48,  # Increase to match x-axis
                    family='Montserrat, sans-serif',
                    color='#ffffff',
                    weight="bold"
                )
            ),
            linecolor='#ffffff',  # White axis lines
            linewidth=2
        ),
        font=dict(
            color='#ffffff',  # White font for all text
            size=36,  # Uniform font size
            family='Montserrat, sans-serif',
            weight="bold"
        ),
        # Refined colorway for better visibility and differentiation
        colorway=["#FFFF00", "#33D7FF", "#A463FF", "#FFD700", 
                  "#ff4081", "#ffc107", "#00c4a0", "#a0aec0"],
        title=dict(
            text='',
            font=dict(
                size=64,  # **Big Boost in Title Size**
                color='#ffffff',
                family='Montserrat, sans-serif',
                weight="bold"
            ),
            x=0.5,  # Center title
            y=0.97  # Push title higher
        )
    ),
    data=dict(
        scatter=[
            go.Scatter(
                line=dict(width=5)  # Increased line width for better visibility
            )
        ]
    )
)

# Register the updated HorizonAnalytics template
pio.templates['HorizonAnalytics'] = HorizonAnalytics
pio.templates.default = 'HorizonAnalytics'

# %% [markdown]
# #### https://plotly.com/python/builtin-colorscales/
# #### https://www.who.int/data/gho/data/indicators/indicator-details/GHO/prevalence-of-obesity-among-adults-bmi--30-(age-standardized-estimate)-(-)6
# #### https://github.com/johan/world.geo.json
# #### https://pacific-data.sprep.org/dataset/pacific-island-region-spatial-data
# #### https://github.com/topojson/world-atlas/blob/master/README.md

# %%
import requests
import pandas as pd

# World Bank API indicator for fertility rate
indicator = "SP.DYN.TFRT.IN"
base_url = f"http://api.worldbank.org/v2"

# Get list of all countries (and groupings) from World Bank
def get_country_metadata():
    country_url = f"{base_url}/country?format=json&per_page=400"
    r = requests.get(country_url)
    total_pages = r.json()[0]['pages']
    country_info = []
    for page in range(1, total_pages + 1):
        r = requests.get(f"{country_url}&page={page}")
        country_info.extend(r.json()[1])
    return {
        c['id']: c['region']['value'] != "Aggregates"
        for c in country_info
    }

# Build a lookup of country_code -> is_country (True/False)
country_lookup = get_country_metadata()

# Get fertility data
data_url = f"{base_url}/country/all/indicator/{indicator}?format=json&per_page=20000"
first_page = requests.get(data_url).json()
total_pages = first_page[0]['pages']

all_data = []
for page in range(1, total_pages + 1):
    page_url = f"{data_url}&page={page}"
    r = requests.get(page_url)
    entries = r.json()[1]
    for entry in entries:
        code = entry['countryiso3code']
        if entry['value'] is not None:
            all_data.append({
                "country_name": entry['country']['value'],
                "country_code": code,
                "year": int(entry['date']),
                "fertility_rate": entry['value'],
                "is_country": country_lookup.get(code, False)
            })

# Save to CSV
df = pd.DataFrame(all_data)
df.to_csv("d_fertility.csv", index=False)
print("Saved d_fertility.csv successfully.")
# Out:
# Saved d_fertility.csv successfully.

# %% [markdown]
# ## tidy_country_names()

# %%
import pandas as pd

def tidy_country_names(csv_path):
    # Define the country name replacements
    replacements = {
        "Democratic People's Republic of Korea": "North Korea",
        "United Republic of Tanzania": "Tanzania",
        "Netherlands (Kingdom of the)": "Netherlands",
        "Venezuela (Bolivarian Republic of)": "Venezuela",
        "Iran (Islamic Republic of)": "Iran",
        "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
        "Bolivia (Plurinational State of)": "Bolivia",
        "Syrian Arab Republic": "Syria",
        "occupied Palestinian territory, including east Jerusalem": "Palestine",
        "Micronesia (Federated States of)": "Micronesia",
        "Democratic Republic of the Congo": "DR Congo",
        "Republic of Korea": "South Korea",
        "Lao People's Democratic Republic": "Lao",
        "Viet Nam": "Vietnam",
        "Russian Federation": "Russia",
        "United States of America": "United States",
        "Republic of Moldova": "Moldova",
        "Saint Vincent and the Grenadines": "St. Vincent & Grenadines",
        "St. Vincent and the Grenadines": "St. Vincent & Grenadines",
        "West Bank and Gaza": "Palestine",
        "Yemen, Rep.": "Yemen",
        "Venezuela, RB": "Venezuela",
        "Micronesia, Fed. Sts.": "Micronesia",
        "Macao SAR, China": "Macao",
        "Lao PDR": "Lao",
        "Kyrgyz Republic": "Kyrgyzstan",
        "Korea, Rep.": "South Korea",
        "Korea, Dem. People's Rep.": "North Korea",
        "Iran, Islamic Rep.": "Iran",
        "Hong Kong SAR, China": "Hong Kong",
        "Gambia, The": "Gambia",
        "Egypt, Arab Rep.": "Egypt",
        "Congo, Rep.": "Congo",
        "Congo, Dem. Rep.": "DR Congo",
        "Bahamas, The": "The Bahamas",
        "St. Martin (French part)": "St. Martin (French)",
        "St. Martin (Dutch part)": "St. Martin (Dutch)"

    }

    # Read CSV
    df = pd.read_csv(csv_path)

    # Replace country names
    df["country_name"] = df["country_name"].replace(replacements)

    # Overwrite CSV
    df.to_csv(csv_path, index=False)

    print(f"✅ Tidied and saved: {csv_path}")

tidy_country_names("d_fertility.csv")
# Out:
# ✅ Tidied and saved: d_fertility.csv

# %%
import pandas as pd

# Load the full dataset
df = pd.read_csv("d_fertility.csv")

# Filter for actual countries
df_countries = df[df["is_country"] == True]

# Save to new CSV
df_countries.to_csv("d_country_fertility.csv", index=False)
print("Saved d_country_fertility.csv successfully.")
# Out:
# Saved d_country_fertility.csv successfully.

# %% [markdown]
# ## filter_csv()

# %%
import pandas as pd
from typing import Union, List

def filter_csv(input_path="d_fertility.csv", output_path="d_country_fertility.csv", years: Union[int, List[int], None] = None):
    # Load dataset
    df = pd.read_csv(input_path)

    # Filter for actual countries
    df_filtered = df[df["is_country"] == True]

    # Optional: filter by year(s)
    if years is not None:
        if isinstance(years, int):
            years = [years]
        df_filtered = df_filtered[df_filtered["year"].isin(years)]

    # Save filtered dataset
    df_filtered.to_csv(output_path, index=False)
    print(f"Saved {output_path} successfully.")

# %% [markdown]
# ## order_csv()

# %%
import pandas as pd

def order_csv(csv_path, column_name, direction="asc"):
    # Read the CSV
    df = pd.read_csv(csv_path)

    # Check sort direction
    ascending = True if direction.lower() == "asc" else False

    # Sort the DataFrame
    df_sorted = df.sort_values(by=column_name, ascending=ascending)

    # Save back to the same file
    df_sorted.to_csv(csv_path, index=False)

    print(f"✅ Sorted by '{column_name}' ({direction}) and saved: {csv_path}")

# %% [markdown]
# ## load_world_geojson()

# %%
import geopandas as gpd
import requests

def load_world_geojson(source='local'):
    """
    Load world map from a local simplified GeoJSON or a simplified online version.

    Parameters:
        source (str): 'local' or 'web'

    Returns:
        GeoDataFrame or dict: GeoDataFrame if local, dict if web
    """
    if source == 'local':
        local_geojson_path = "../ne_10m_admin_0_countries_lakes/world_simplified.geojson"
        try:
            print(f"📁 Loading local simplified GeoJSON from: {local_geojson_path}")
            return gpd.read_file(local_geojson_path)
        except FileNotFoundError:
            raise FileNotFoundError(f"❌ GeoJSON file not found at: {local_geojson_path}")

    elif source == 'web':
        print("🌍 Loading simplified GeoJSON from Johan's GitHub...")
        geojson_url = "https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json"
        response = requests.get(geojson_url)
        response.raise_for_status()
        return response.json()

    else:
        raise ValueError("Invalid source. Use 'local' or 'web'.")

# %%
filter_csv(years=2022)
order_csv("d_country_fertility.csv", column_name="fertility_rate", direction="asc")
world_geojson = load_world_geojson('web')
# Out:
# Saved d_country_fertility.csv successfully.
# ✅ Sorted by 'fertility_rate' (asc) and saved: d_country_fertility.csv
# 🌍 Loading simplified GeoJSON from Johan's GitHub...

# %%
small_countries_coords = {
    'TON': (-21.2, -175.2),
    'WSM': (-13.8, -172.1),
    'NRU': (-0.52, 166.93),
    'KIR': (1.87, 173.0),
    'PLW': (7.5, 134.5),
    'MHL': (7.1, 171.0),
    'FSM': (6.9, 158.2),
    'VUT': (-16.0, 167.0),
    'TUV': (-7.1, 179.2),
    'NIU': (-19.05, -169.86),
    'COK': (-21.2, -159.8),
    'TKL': (-9.2, -171.8),
    'ASM': (-14.3, -170.7),
    'CPV': (15.1, -23.6),
    'STP': (0.2, 6.6),
    'COM': (-11.6, 43.3),
    'LUX': (49.8, 6.1),
    'AND': (42.5, 1.5),
    'LCA': (13.9, -60.98),
    'ATG': (17.1, -61.8),
    'DMA': (15.4, -61.4),
    'VCT': (13.25, -61.2),
    'KNA': (17.3, -62.7),
    'BRB': (13.1, -59.6),
    'BMU': (32.3, -64.8),
    'MDV': (3.2, 73.2),
    'SGP': (1.35, 103.8),
    'BHR': (26.0, 50.5),
    'QAT': (25.3, 51.5),
    'DJI': (11.8, 42.6),
    'GMB': (13.5, -15.5),
    'SYC': (-4.6, 55.5),
    'MUS': (-20.2, 57.5),
    'GNQ': (1.6, 10.5),
    'GNB': (11.8, -15.2),
    'SLB': (-9.6, 160.2),
    'PYF': (-17.6797, -149.4068),  # French Polynesia (Tahiti approx.)
    'HKG': (22.3, 114.2),
    'PRI': (18.2, -66.5),
    'VGB': (18.4, -64.6),
    'MAC': (22.2, 113.6),           # Macao
    'MLT': (35.9, 14.5),             # Malta 
    'ABW': (12.5, -69.97),     # Aruba 
    'CUW': (12.2, -69.0),      # Curaçao
    'CYP': (35.1, 33.4),       # Cyprus
    'JAM': (18.1, -77.3),      # Jamaica
    'BHS': (25.03, -77.4),     # The Bahamas
    'CHI': (49.5, -2.5),       # Channel Islands (approx. between Jersey and Guernsey)
    'GIB': (36.1, -5.35),       # Gibraltar
    'VIR': (18.34, -64.89),    # US Virgin Islands
    'NCL': (-22.27, 166.44),   # New Caledonia
    'FRO': (62.0, -6.79),      # Faroe Islands
    'MAF': (18.07, -63.05),    # St Martin (French)
    'SXM': (18.04, -63.07),    # St Martin (Dutch)
    'GUM': (13.44, 144.79),    # Guam
    'OMN': (21.5, 55.9)        # Oman (added as it's actually a full country)
}

# %% [markdown]
# ## map_frames ()

# %%
import pandas as pd
import plotly.graph_objects as go
import os
import shutil

def map_frames(
    csv_filename,
    world_geojson,
    small_countries_coords,
    metric='obesity_rate', 
    plot_height=1080,
    plot_width=1920,
    color_min='255,255,0',
    color_mid='255,165,0',
    color_max='255,0,0',
    parent_folder='2023-03_obesity',
    output_folder='frames_world',
    clear=True,
    marker_size=10,
    min_color_percentile=5,
    max_color_percentile=95
):
    # Load data
    df = pd.read_csv(csv_filename)
    latest_year = df['year'].max()
    df = df[df['year'] == latest_year].reset_index(drop=True)

    # Compute color scale values based on input percentiles
    color_min_value = df[metric].quantile(min_color_percentile / 100)
    color_max_value = df[metric].quantile(max_color_percentile / 100)
    color_mid_value = df[metric].mean()

    print(f"🎨 Color scale range for '{metric}':")
    print(f"   Min (p{min_color_percentile}): {color_min_value:.2f}")
    print(f"   Mid (mean): {color_mid_value:.2f}")
    print(f"   Max (p{max_color_percentile}): {color_max_value:.2f}")

    geojson = world_geojson

    all_countries = pd.DataFrame({
        'country_code': [
            feature.get('id') or feature['properties'].get('iso_a3')
            for feature in geojson['features']
        ]
    })

    # Convert small country coords to DataFrame
    small_countries = pd.DataFrame([
        {'country_code': code, 'lat': lat, 'lon': lon}
        for code, (lat, lon) in small_countries_coords.items()
    ])

    # Set output path
    output_path = f"/Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/{parent_folder}/{output_folder}"
    if clear and os.path.exists(output_path):
        shutil.rmtree(output_path)
    os.makedirs(output_path, exist_ok=True)

    for i in range(1, len(df) + 1):
        df_partial = df.iloc[:i]
        df_merged = all_countries.merge(
            df_partial[['country_code', 'country_name', metric]],
            on='country_code', how='left'
        )

        small_data = small_countries.merge(
            df_partial[['country_code', metric]],
            on='country_code',
            how='left'
        )
        small_data = small_data[small_data[metric].notna()]

        fig = go.Figure()

        # Choropleth base layer
        fig.add_trace(go.Choropleth(
            geojson=geojson,
            locations=df_merged['country_code'],
            z=df_merged[metric],
            locationmode='ISO-3',
            colorscale=[
                [0.0, f'rgb({color_min})'],
                [0.5, f'rgb({color_mid})'],
                [1.0, f'rgb({color_max})']
            ],
            zmin=color_min_value,
            zmax=color_max_value,
            colorbar_title=metric.replace("_", " ").capitalize(),
            text=df_merged['country_name'],
            hoverinfo='location+z+text',
            marker_line_color='white',
            marker_line_width=1.5,
        ))

        # Small country markers
        fig.add_trace(go.Scattergeo(
            lon=small_data['lon'],
            lat=small_data['lat'],
            mode='markers',
            marker=dict(
                size=marker_size,
                color=small_data[metric],
                colorscale=[
                    [0.0, f'rgb({color_min})'],
                    [0.5, f'rgb({color_mid})'],
                    [1.0, f'rgb({color_max})']
                ],
                cmin=color_min_value,
                cmax=color_max_value,
                colorbar=None,
                line=dict(width=3.5, color='white'),
                opacity=1.0
            ),
            hoverinfo='skip',
            showlegend=False
        ))

        # Global map settings
        fig.update_geos(
            showcountries=True,
            countrycolor="white",
            showframe=False,
            showcoastlines=False,
            showlakes=False,
            bgcolor='rgba(0,0,0,0)',
            lataxis_range=[-60, 90],
            projection_rotation={"lon": 40}
        )

        fig.update_layout(
            margin={"r": 0, "t": 0, "l": 0, "b": 0},
            paper_bgcolor='rgba(0,0,0,0)',
            plot_bgcolor='rgba(0,0,0,0)',
            height=plot_height,
            width=plot_width,
            coloraxis_colorbar=dict(
                len=0.5,
                yanchor='middle',
                y=0.5
            )
        )

        # Save frame
        filepath = f"{output_path}/{i:04d}.png"
        fig.write_image(filepath, scale=1)

        current_country = df_partial.iloc[-1]['country_name']
        print(f"✅ Saved {filepath} – added: {current_country}")

# %%
map_frames(
    csv_filename="d_country_fertility.csv",
    world_geojson=world_geojson,
    small_countries_coords=small_countries_coords,
    metric="fertility_rate",
    plot_height=1080,
    plot_width=1920,
    color_min = "143,217,251",  # light blue
    color_mid = "0,0,255",  # medium blue
    color_max = "17,17,132",     # dark blue
    parent_folder="2023-03_fertility",
    output_folder="frames_world",
    clear=True,
    marker_size=18,
    min_color_percentile=5,
    max_color_percentile=95
)
# Out:
# 🎨 Color scale range for 'fertility_rate':
#    Min (p5): 1.25
#    Mid (mean): 2.48
#    Max (p95): 4.66
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0001.png – added: Hong Kong
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0002.png – added: South Korea
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0003.png – added: Puerto Rico
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0004.png – added: British Virgin Islands
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0005.png – added: Singapore
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0006.png – added: Macao
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0007.png – added: Malta
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0008.png – added: Spain
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0009.png – added: China
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0010.png – added: Aruba
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0011.png – added: Italy
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0012.png – added: Japan
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0013.png – added: Poland
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0014.png – added: Ukraine
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0015.png – added: Lithuania
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0016.png – added: Curacao
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0017.png – added: Bermuda
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0018.png – added: Luxembourg
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0019.png – added: Cyprus
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0020.png – added: Thailand
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0021.png – added: Mauritius
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0022.png – added: Finland
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0023.png – added: Canada
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0024.png – added: Jamaica
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0025.png – added: Bosnia and Herzegovina
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0026.png – added: Albania
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0027.png – added: The Bahamas
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0028.png – added: St. Lucia
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0029.png – added: Switzerland
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0030.png – added: Bhutan
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0031.png – added: Estonia
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0032.png – added: Norway
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0033.png – added: Austria
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0034.png – added: Russia
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0035.png – added: Greece
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0036.png – added: Portugal
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0037.png – added: United Arab Emirates
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0151.png – added: Timor-Leste
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0152.png – added: Kazakhstan
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0153.png – added: Tajikistan
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0154.png – added: Tuvalu
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0155.png – added: Papua New Guinea
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0156.png – added: Tonga
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0157.png – added: Namibia
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0158.png – added: Kiribati
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0159.png – added: Kenya
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0160.png – added: Uzbekistan
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0161.png – added: Pakistan
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0162.png – added: Palestine
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0163.png – added: Zimbabwe
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0164.png – added: Iraq
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0165.png – added: Gabon
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0166.png – added: Nauru
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0167.png – added: Ghana
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0168.png – added: Vanuatu
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0169.png – added: Yemen
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0170.png – added: Rwanda
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0171.png – added: Sao Tome and Principe
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0172.png – added: Eritrea
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0173.png – added: Madagascar
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0174.png – added: Malawi
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0175.png – added: Samoa
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0176.png – added: Sierra Leone
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0177.png – added: Comoros
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0178.png – added: Solomon Islands
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0179.png – added: Guinea-Bissau
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0180.png – added: Liberia
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0181.png – added: Ethiopia
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0182.png – added: Congo
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0183.png – added: Equatorial Guinea
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0184.png – added: Togo
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0185.png – added: Zambia
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0186.png – added: Guinea
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0187.png – added: Senegal
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0188.png – added: South Sudan
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0189.png – added: Mauritania
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0190.png – added: Cote d'Ivoire
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0191.png – added: Cameroon
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0192.png – added: Sudan
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0193.png – added: Uganda
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0194.png – added: Afghanistan
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0195.png – added: Mozambique
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0196.png – added: Gambia
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0197.png – added: Tanzania
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0198.png – added: Burkina Faso
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0199.png – added: Benin
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0200.png – added: Burundi
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0201.png – added: Nigeria
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0202.png – added: Angola
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0203.png – added: Mali
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0204.png – added: Central African Republic
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0205.png – added: DR Congo
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0206.png – added: Somalia
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0207.png – added: Chad
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world/0208.png – added: Niger

# %% [markdown]
# ## text_frames ()

# %%
from PIL import Image, ImageDraw, ImageFont
import pandas as pd
import os
import shutil

def interpolate_color(val, min_val, mid_val, max_val, rgb_min, rgb_mid, rgb_max):
    if val <= mid_val:
        ratio = (val - min_val) / (mid_val - min_val) if mid_val > min_val else 0
    else:
        ratio = 0.5 + 0.5 * ((val - mid_val) / (max_val - mid_val)) if max_val > mid_val else 1

    ratio = max(0, min(1, ratio))  # Ensure ratio is within [0, 1]

    if ratio <= 0.5:
        r_ratio = ratio * 2
        return tuple([
            int(rgb_min[i] + r_ratio * (rgb_mid[i] - rgb_min[i]))
            for i in range(3)
        ])
    else:
        r_ratio = (ratio - 0.5) * 2
        return tuple([
            int(rgb_mid[i] + r_ratio * (rgb_max[i] - rgb_mid[i]))
            for i in range(3)
        ])

def save_text_component(text, text_color, outline_color, font, image_width, image_height, x, y, filepath):
    # Create transparent image
    img = Image.new('RGBA', (image_width, image_height), (0, 0, 0, 0))
    draw = ImageDraw.Draw(img)

    # Draw outline
    offset = 2
    for dx in [-offset, 0, offset]:
        for dy in [-offset, 0, offset]:
            if dx == 0 and dy == 0:
                continue
            draw.text((x + dx, y + dy), text, font=font, fill=outline_color)
    
    # Draw main text
    draw.text((x, y), text, font=font, fill=text_color)
    img.save(filepath)
    print(f"🖼️ Saved {filepath}")

def extract_text(
    csv_filename,
    parent_folder='2023-03_obesity',
    output_folder='frames_text',
    output_folder_suffix='',
    metric='fertility_rate',
    font_type='ExtraBold',
    font_size=100,
    image_width=1920,
    image_height=1080,
    color_min='143,217,251',
    color_mid='0,0,255',
    color_max='17,17,132',
    min_color_percentile=5,
    max_color_percentile=95,
    rank_border=112,
    clear=True
):
    # Parse colors
    rgb_min = tuple(map(int, color_min.split(',')))
    rgb_mid = tuple(map(int, color_mid.split(',')))
    rgb_max = tuple(map(int, color_max.split(',')))

    # Output path
    full_output_folder = os.path.join(parent_folder, output_folder + output_folder_suffix)
    base_output_path = os.path.join(
        "/Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics",
        full_output_folder
    )
    
    if clear and os.path.exists(base_output_path):
        shutil.rmtree(base_output_path)
    os.makedirs(base_output_path, exist_ok=True)

    # Create subfolders for each text type
    text_types = ['title', 'value', 'rank', 'country']
    text_paths = {text_type: os.path.join(base_output_path, text_type) for text_type in text_types}
    for path in text_paths.values():
        os.makedirs(path, exist_ok=True)

    # Load and filter data
    df = pd.read_csv(csv_filename)
    latest_year = df['year'].max()
    df = df[df['year'] == latest_year].reset_index(drop=True)

    # Compute thresholds
    color_min_value = df[metric].quantile(min_color_percentile / 100)
    color_max_value = df[metric].quantile(max_color_percentile / 100)
    color_mid_value = df[metric].mean()

    # Add ranks
    df['rank'] = df[metric].rank(method='min', ascending=False).astype(int)

    # Load font
    font_path = os.path.join("..", "Montserrat", f"Montserrat-{font_type}.ttf")
    try:
        font = ImageFont.truetype(font_path, font_size)
    except IOError:
        print(f"Montserrat font '{font_type}' not found. Using default font.")
        font = ImageFont.load_default()

    for i in range(1, len(df) + 1):
        row = df.iloc[i - 1]
        country = row['country_name']
        rate = round(row[metric], 2)
        rank = row['rank']

        # Determine text color
        text_color = interpolate_color(
            rate, color_min_value, color_mid_value, color_max_value,
            rgb_min, rgb_mid, rgb_max
        )

        # Determine outline color based on rank
        if rank <= rank_border:
            outline_color = (255, 255, 255)
        else:
            outline_color = (255, 255, 255)

        # Define text components
        texts = {
            'title': "KIDS / WOMAN",
            'value': str(rate),
            'rank': f"#{rank}",
            'country': country.upper()
        }

        # Save each text component individually, all left-indented
        x = 100  # Left-indented
        y_positions = {
            'title': 100,
            'value': 250,
            'rank': 400,
            'country': 550
        }

        for text_type, text in texts.items():
            y = y_positions[text_type]
            filepath = os.path.join(text_paths[text_type], f"{i:04d}.png")
            save_text_component(text, text_color, outline_color, font, image_width, image_height, x, y, filepath)

# %%
extract_text(
    csv_filename="d_country_fertility.csv",
    parent_folder="2023-03_fertility",
    output_folder="frames_text",
    output_folder_suffix="",
    metric="fertility_rate",
    font_type="ExtraBold",
    font_size=100,
    image_width=1920,
    image_height=1080,
    color_min = "143,217,251",  # light blue
    color_mid = "0,0,255",  # medium blue
    color_max = "17,17,132",     # dark blue
    min_color_percentile=5,
    max_color_percentile=95,
    rank_border=112,
    clear=True
)
# Out:
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0001.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0001.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0001.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0001.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0002.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0002.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0002.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0002.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0003.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0003.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0003.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0003.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0004.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0004.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0004.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0004.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0005.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0005.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0005.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0005.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0006.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0006.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0006.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0006.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0007.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0007.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0007.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0007.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0008.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0008.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0008.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0008.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0009.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0009.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0009.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0009.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0010.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0010.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0010.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0010.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0011.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/
png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0175.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0176.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0176.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0176.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0176.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0177.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0177.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0177.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0177.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0178.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0178.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0178.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0178.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0179.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0179.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0179.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0179.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0180.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0180.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0180.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0180.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0181.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0181.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0181.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0181.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0182.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0182.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0182.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0182.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0183.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0183.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0183.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0183.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0184.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0184.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0184.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0184.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0185.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0185.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0185.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0185.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0186.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0186.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0186.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0186.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0187.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0187.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0187.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0187.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0188.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0188.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0188.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0188.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0189.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0189.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0189.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0189.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0190.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0190.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0190.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0190.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0191.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0191.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0191.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0191.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0192.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0192.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0192.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0192.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0193.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0193.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0193.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0193.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0194.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0194.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0194.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0194.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0195.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0195.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0195.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0195.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0196.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0196.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0196.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0196.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0197.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0197.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0197.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0197.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0198.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0198.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0198.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0198.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0199.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0199.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0199.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0199.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0200.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0200.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0200.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0200.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0201.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0201.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0201.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0201.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0202.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0202.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0202.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0202.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0203.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0203.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0203.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0203.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0204.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0204.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0204.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0204.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0205.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0205.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0205.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0205.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0206.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0206.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0206.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0206.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0207.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0207.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0207.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0207.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/title/0208.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/value/0208.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/rank/0208.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_text/country/0208.png

# %%
import pandas as pd
import os
import shutil
import requests
from PIL import Image
from io import BytesIO
from pycountry import countries

def save_flag_frames(
    csv_filename,
    parent_folder='2023-03_obesity',
    output_folder='frames_flag',
    image_width=1920,
    image_height=1080,
    clear=True
):
    # Output path
    output_path = os.path.join(
        "/Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics",
        parent_folder,
        output_folder
    )

    if clear and os.path.exists(output_path):
        shutil.rmtree(output_path)
    os.makedirs(output_path, exist_ok=True)

    # Load data and preserve original order
    df = pd.read_csv(csv_filename)
    latest_year = df['year'].max()
    df = df[df['year'] == latest_year].reset_index(drop=True)
    df = df[df["is_country"] == True]

    # Create ISO-3 to ISO-2 mapping
    iso_map = {c.alpha_3: c.alpha_2.lower() for c in countries if hasattr(c, 'alpha_3')}

    for i in range(len(df)):
        row = df.iloc[i]
        code3 = row['country_code']
        country = row['country_name']
        code2 = iso_map.get(code3)

        if not code2:
            print(f"⚠️ No ISO-2 code for {country} ({code3})")
            continue

        url = f"https://flagcdn.com/w320/{code2}.png"
        try:
            response = requests.get(url)
            response.raise_for_status()
            flag = Image.open(BytesIO(response.content)).convert("RGBA")
        except Exception as e:
            print(f"❌ Failed to load flag for {country} ({code3}): {e}")
            continue

        # Resize and center the flag on a transparent canvas
        flag_aspect = flag.width / flag.height
        target_height = image_height
        target_width = int(target_height * flag_aspect)
        flag = flag.resize((target_width, target_height), Image.LANCZOS)

        img = Image.new("RGBA", (image_width, image_height), (0, 0, 0, 0))
        x = (image_width - flag.width) // 2
        y = (image_height - flag.height) // 2
        img.paste(flag, (x, y), flag)

        filepath = os.path.join(output_path, f"{i+1:04d}.png")
        img.save(filepath)
        print(f"🏁 Saved {filepath} – {country}")

# Example usage
save_flag_frames(
    csv_filename='d_country_fertility.csv',
    parent_folder='2023-03_fertility',
    output_folder='frames_flag' 
)
# Out:
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0001.png – Hong Kong
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0002.png – South Korea
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0003.png – Puerto Rico
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0004.png – British Virgin Islands
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0005.png – Singapore
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0006.png – Macao
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0007.png – Malta
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0008.png – Spain
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0142.png – Haiti
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0143.png – Mongolia
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0144.png – Eswatini
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0145.png – Jordan
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0146.png – Kyrgyzstan
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0147.png – Algeria
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0148.png – Egypt
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0149.png – Israel
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0150.png – Lesotho
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0151.png – Timor-Leste
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0152.png – Kazakhstan
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0153.png – Tajikistan
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0154.png – Tuvalu
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0155.png – Papua New Guinea
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0156.png – Tonga
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0157.png – Namibia
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0158.png – Kiribati
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0159.png – Kenya
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0160.png – Uzbekistan
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0161.png – Pakistan
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0162.png – Palestine
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0163.png – Zimbabwe
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0164.png – Iraq
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0165.png – Gabon
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0166.png – Nauru
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0167.png – Ghana
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0168.png – Vanuatu
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0169.png – Yemen
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0170.png – Rwanda
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0171.png – Sao Tome and Principe
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0172.png – Eritrea
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0173.png – Madagascar
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0174.png – Malawi
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0175.png – Samoa
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0176.png – Sierra Leone
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0177.png – Comoros
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0178.png – Solomon Islands
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0179.png – Guinea-Bissau
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0180.png – Liberia
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0181.png – Ethiopia
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0182.png – Congo
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0183.png – Equatorial Guinea
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0184.png – Togo
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0185.png – Zambia
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0186.png – Guinea
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0187.png – Senegal
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0188.png – South Sudan
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0189.png – Mauritania
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0190.png – Cote d'Ivoire
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0191.png – Cameroon
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0192.png – Sudan
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0193.png – Uganda
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0194.png – Afghanistan
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0195.png – Mozambique
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0196.png – Gambia
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0197.png – Tanzania
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0198.png – Burkina Faso
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0199.png – Benin
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0200.png – Burundi
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0201.png – Nigeria
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0202.png – Angola
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0203.png – Mali
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0204.png – Central African Republic
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0205.png – DR Congo
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0206.png – Somalia
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0207.png – Chad
# 🏁 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_flag/0208.png – Niger

# %% [markdown]
# ## history_frames()

# %%
def map_frames_hardcoded(
    csv_filename,
    world_geojson,
    small_countries_coords,
    year,
    index,
    metric='obesity_rate',
    plot_height=1080,
    plot_width=1920,
    parent_folder='2023-03_obesity',
    output_folder='frames_world',
    clear=False,
    marker_size=10
):
    import pandas as pd
    import plotly.graph_objects as go
    import os
    import shutil

    # Hardcoded color scale values
    color_min = "143,217,251"  # light blue
    color_mid = "0,0,255"  # medium blue
    color_max = "17,17,132"     # dark blue
    color_min_value = 1.25
    color_mid_value = 2.47
    color_max_value = 4.66

    # Load data
    df = pd.read_csv(csv_filename)
    df = df[df['year'] == year].reset_index(drop=True)

    geojson = world_geojson

    all_countries = pd.DataFrame({
        'country_code': [
            feature.get('id') or feature['properties'].get('iso_a3')
            for feature in geojson['features']
        ]
    })

    # Convert small country coords dict to DataFrame
    small_countries = pd.DataFrame([
        {'country_code': code, 'lat': lat, 'lon': lon}
        for code, (lat, lon) in small_countries_coords.items()
    ])

    # Prepare output directory
    output_path = f"/Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/{parent_folder}/{output_folder}"
    if clear and os.path.exists(output_path):
        shutil.rmtree(output_path)
    os.makedirs(output_path, exist_ok=True)

    # Merge full data
    df_merged = all_countries.merge(
        df[["country_code", "country_name", metric]],
        on="country_code", how="left"
    )

    small_data = small_countries.merge(
        df[["country_code", metric]],
        on="country_code",
        how="left"
    )
    small_data = small_data[small_data[metric].notna()]

    fig = go.Figure()

    # Choropleth
    fig.add_trace(go.Choropleth(
        geojson=geojson,
        locations=df_merged['country_code'],
        z=df_merged[metric],
        locationmode='ISO-3',
        colorscale=[
            [0.0, f'rgb({color_min})'],
            [0.5, f'rgb({color_mid})'],
            [1.0, f'rgb({color_max})']
        ],
        zmin=color_min_value,
        zmax=color_max_value,
        colorbar_title=metric.replace("_", " ").capitalize(),
        text=df_merged['country_name'],
        hoverinfo='location+z+text',
        marker_line_color='white',
        marker_line_width=1.5,
    ))

    # Small country markers
    fig.add_trace(go.Scattergeo(
        lon=small_data['lon'],
        lat=small_data['lat'],
        mode='markers',
        marker=dict(
            size=marker_size,
            color=small_data[metric],
            colorscale=[
                [0.0, f'rgb({color_min})'],
                [0.5, f'rgb({color_mid})'],
                [1.0, f'rgb({color_max})']
            ],
            cmin=color_min_value,
            cmax=color_max_value,
            colorbar=None,
            line=dict(width=3.5, color='white'),
            opacity=1.0
        ),
        hoverinfo='skip',
        showlegend=False
    ))

    # Global map layout
    fig.update_geos(
        showcountries=True,
        countrycolor="white",
        showframe=False,
        showcoastlines=False,
        showlakes=False,
        bgcolor='rgba(0,0,0,0)',
        lataxis_range=[-60, 90],
        projection_rotation={"lon": 40}
    )

    fig.update_layout(
        margin={"r": 0, "t": 0, "l": 0, "b": 0},
        paper_bgcolor='rgba(0,0,0,0)',
        plot_bgcolor='rgba(0,0,0,0)',
        height=plot_height,
        width=plot_width,
        coloraxis_colorbar=dict(
            len=0.5,
            yanchor='middle',
            y=0.5
        )
    )

    # Save frame
    filepath = f"{output_path}/{index:04d}.png"
    fig.write_image(filepath, scale=1)
    print(f"✅ Saved {filepath} for year {year}")

# %%
import pandas as pd
import json

# Set file path and read dataset
csv_filename = "d_fertility.csv"
df = pd.read_csv(csv_filename)
df = df[df["is_country"] == True]

# Get all unique years in order
years = sorted(df["year"].dropna().unique())

# Generate one map per year
for i, year in enumerate(years, start=1):
    map_frames_hardcoded(
        csv_filename="d_fertility.csv",
        world_geojson=world_geojson,
        small_countries_coords=small_countries_coords,
        year=year,
        index=i,
        metric="fertility_rate",
        plot_height=1080,
        plot_width=1920,
        parent_folder="2023-03_fertility",
        output_folder="frames_world_history",
        clear=False,  # important to avoid deleting output folder each time
        marker_size=18
    )
# Out:
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0001.png for year 1960
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0002.png for year 1961
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0003.png for year 1962
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0004.png for year 1963
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0005.png for year 1964
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0006.png for year 1965
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0007.png for year 1966
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0008.png for year 1967
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0009.png for year 1968
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0010.png for year 1969
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0011.png for year 1970
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0012.png for year 1971
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0013.png for year 1972
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0014.png for year 1973
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0015.png for year 1974
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0016.png for year 1975
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0017.png for year 1976
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0018.png for year 1977
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0019.png for year 1978
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0020.png for year 1979
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0021.png for year 1980
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0022.png for year 1981
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0023.png for year 1982
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0024.png for year 1983
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0025.png for year 1984
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0026.png for year 1985
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0027.png for year 1986
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0028.png for year 1987
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0029.png for year 1988
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0030.png for year 1989
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0031.png for year 1990
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0032.png for year 1991
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0033.png for year 1992
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0034.png for year 1993
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0035.png for year 1994
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0036.png for year 1995
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0037.png for year 1996
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0038.png for year 1997
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0039.png for year 1998
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0040.png for year 1999
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0041.png for year 2000
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0042.png for year 2001
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0043.png for year 2002
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0044.png for year 2003
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0045.png for year 2004
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0046.png for year 2005
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0047.png for year 2006
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0048.png for year 2007
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0049.png for year 2008
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0050.png for year 2009
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0051.png for year 2010
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0052.png for year 2011
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0053.png for year 2012
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0054.png for year 2013
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0055.png for year 2014
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0056.png for year 2015
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0057.png for year 2016
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0058.png for year 2017
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0059.png for year 2018
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0060.png for year 2019
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0061.png for year 2020
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0062.png for year 2021
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_world_history/0063.png for year 2022

# %%
from PIL import Image, ImageDraw, ImageFont
import pandas as pd
import os
import shutil

def extract_text_all_years(
    csv_filename,
    parent_folder='2023-03_obesity',
    output_folder='frames_years_only',
    font_type='ExtraBold',
    font_size=200,
    image_width=1920,
    image_height=1080,
    alignment='center',
    clear=True
):
    # Colors
    text_color = (0, 0, 0, 0)  # black
    outline_color = (255, 255, 255)  # white

    # Output path
    output_path = os.path.join(
        "/Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics",
        parent_folder,
        output_folder
    )
    if clear and os.path.exists(output_path):
        shutil.rmtree(output_path)
    os.makedirs(output_path, exist_ok=True)

    # Load data
    df = pd.read_csv(csv_filename)

    # Load font
    font_path = os.path.join("..", "Montserrat", f"Montserrat-{font_type}.ttf")
    try:
        font = ImageFont.truetype(font_path, font_size)
    except IOError:
        print(f"Montserrat font '{font_type}' not found. Using default font.")
        font = ImageFont.load_default()

    # Unique years (reverse order)
    years = sorted(df['year'].unique(), reverse=True)

    for i, year in enumerate(years, start=1):
        text = str(year)

        # Create transparent image
        img = Image.new('RGBA', (image_width, image_height), (0, 0, 0, 0))
        draw = ImageDraw.Draw(img)

        bbox = draw.textbbox((0, 0), text, font=font)
        text_width = bbox[2] - bbox[0]
        text_height = bbox[3] - bbox[1]

        if alignment == 'left':
            x = 100
        elif alignment == 'right':
            x = image_width - text_width - 100
        else:
            x = (image_width - text_width) / 2

        y = (image_height - text_height) / 2

        # Outline
        offset = 4
        for dx in [-offset, 0, offset]:
            for dy in [-offset, 0, offset]:
                if dx == 0 and dy == 0:
                    continue
                draw.text((x + dx, y + dy), text, font=font, fill=outline_color)

        # Main text
        draw.text((x, y), text, font=font, fill=text_color)

        filepath = os.path.join(output_path, f"{i:04d}.png")
        img.save(filepath)
        print(f"🖼️ Saved {filepath}")

# %%
extract_text_all_years(
    csv_filename='d_fertility.csv',
    parent_folder='2023-03_fertility',
    output_folder='frames_years_only',
    font_type='ExtraBold',
    font_size=200,
    image_width=1920,
    image_height=1080,
    alignment='center',
    clear=True
)
# Out:
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0001.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0002.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0003.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0004.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0005.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0006.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0007.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0008.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0009.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0010.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0011.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0012.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0013.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0014.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0015.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0016.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0017.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0018.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0019.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0020.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0021.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0022.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0023.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0024.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0025.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0026.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0027.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0028.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0029.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0030.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0031.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0032.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0033.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0034.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0035.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0036.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0037.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0038.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0039.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0040.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0041.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0042.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0043.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0044.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0045.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0046.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0047.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0048.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0049.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0050.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0051.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0052.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0053.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0054.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0055.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0056.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0057.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0058.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0059.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0060.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0061.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0062.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_fertility/frames_years_only/0063.png
