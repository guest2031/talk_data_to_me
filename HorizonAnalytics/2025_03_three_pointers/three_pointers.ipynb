# %% [markdown]
# <!-- ### Plotly -->

# %%
import plotly.graph_objects as go
import plotly.io as pio

# Define the updated HorizonAnalytics template
HorizonAnalytics = go.layout.Template(
    layout=go.Layout(
        paper_bgcolor='#0d1b2a',  # Background color
        plot_bgcolor='#0d1b2a',  # Background color
        height=800,
        width=800 * 1.618,
        xaxis=dict(
            anchor='y',
            showgrid=True,
            gridcolor='rgba(255, 255, 255, 0.2)',  # Softer grid lines for contrast
            tickfont=dict(
                size=36,  # Consistent with other elements
                family='Montserrat, sans-serif',
                color='#ffffff',
                weight="bold"
            ),
            title=dict(
                text='',
                font=dict(
                    size=48,  # Increase to match other elements
                    family='Montserrat, sans-serif',
                    color='#ffffff',
                    weight="bold"
                )
            ),
            linecolor='#ffffff',  # White axis lines for contrast
            linewidth=2
        ),
        yaxis=dict(
            anchor='x',
            showgrid=True,
            gridcolor='rgba(255, 255, 255, 0.2)',  # Softer grid lines
            tickfont=dict(
                size=36,  # Consistent with x-axis
                family='Montserrat, sans-serif',
                color='#ffffff',
                weight="bold"
            ),
            title=dict(
                text='',
                font=dict(
                    size=48,  # Increase to match x-axis
                    family='Montserrat, sans-serif',
                    color='#ffffff',
                    weight="bold"
                )
            ),
            linecolor='#ffffff',  # White axis lines
            linewidth=2
        ),
        font=dict(
            color='#ffffff',  # White font for all text
            size=36,  # Uniform font size
            family='Montserrat, sans-serif',
            weight="bold"
        ),
        # Refined colorway for better visibility and differentiation
        colorway=["#FFFF00", "#33D7FF", "#A463FF", "#FFD700", 
                  "#ff4081", "#ffc107", "#00c4a0", "#a0aec0"],
        title=dict(
            text='',
            font=dict(
                size=64,  # **Big Boost in Title Size**
                color='#ffffff',
                family='Montserrat, sans-serif',
                weight="bold"
            ),
            x=0.5,  # Center title
            y=0.97  # Push title higher
        )
    ),
    data=dict(
        scatter=[
            go.Scatter(
                line=dict(width=5)  # Increased line width for better visibility
            )
        ]
    )
)

# Register the updated HorizonAnalytics template
pio.templates['HorizonAnalytics'] = HorizonAnalytics
pio.templates.default = 'HorizonAnalytics'

# %% [markdown]
# <!-- ## Top X Shooters -->

# %%
# from selenium import webdriver
# from selenium.webdriver.chrome.service import Service
# from selenium.webdriver.chrome.options import Options
# from webdriver_manager.chrome import ChromeDriverManager
# from bs4 import BeautifulSoup
# import pandas as pd
# import time

# # Setup Selenium
# options = Options()
# options.headless = True  # Run in headless mode (no GUI)

# # Initialize WebDriver
# driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# # Load the page
# url = "https://www.basketball-reference.com/leaders/fg3_career.html"
# driver.get(url)

# # Wait for JavaScript to render content
# time.sleep(5)  # Adjust if necessary

# # Get page source after JavaScript executes
# soup = BeautifulSoup(driver.page_source, "html.parser")
# driver.quit()

# # Find the correct table
# table = soup.find("table", {"id": "tot"})

# if not table:
#     print("Table not found. The site may be blocking automated access.")
# else:
#     rows = table.find_all("tr", {"data-row": True})  # Extract data rows
#     print(f"Total rows found: {len(rows)}")  # Debugging output

#     ranks, names, num_threes_career, links = [], [], [], []

#     for row in rows[:36]:  # Limit to top 35 players
#         columns = row.find_all("td")

#         if len(columns) < 3:
#             print("Skipping invalid row:", row)  # Debugging output
#             continue  # Skip rows with missing data

#         rank = columns[0].text.strip().replace(".", "")
#         name_tag = columns[1].find("a")  # Extract the <a> tag inside the name column
#         name = name_tag.text.strip() if name_tag else columns[1].text.strip().replace("*", "")  # Get player name
#         link = "https://www.basketball-reference.com" + name_tag["href"] if name_tag else ""  # Get full link

#         threes = columns[2].text.strip()

#         ranks.append(rank)
#         names.append(name)
#         num_threes_career.append(threes)
#         links.append(link)

#     # Create DataFrame with lowercase column names
#     df = pd.DataFrame({
#         "rank": ranks, 
#         "name": names, 
#         "num_threes_career": num_threes_career, 
#         "link": links
#     })

#     # Save as CSV
#     csv_filename = "d_top_shooters.csv"
#     df.to_csv(csv_filename, index=False, encoding="utf-8")

#     print(f"Data saved to {csv_filename}")
# Out:
# Total rows found: 258
# Skipping invalid row: <tr class="thead" data-row="30">
# <th>Rank</th>
# <th>Player</th>
# <th>3P</th>
# </tr>
# Data saved to d_top_shooters.csv

# %% [markdown]
# <!-- ## Per Season stats -->

# %% [markdown]
# <!-- ### f: extract_shooting_stats -->

# %%
# import requests
# from bs4 import BeautifulSoup
# import pandas as pd
# from IPython.core.display import display, HTML

# def extract_shooting_stats(link):
#     """
#     Connects to a Basketball Reference player page and extracts 'season', 'age', '3P', and '3PA' from the 'Totals' table.
    
#     Parameters:
#         link (str): The URL of the player's profile page.
        
#     Returns:
#         DataFrame with 'season' (as a counter), 'age', '3P', and '3PA' columns.
#     """
#     headers = {
#         "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
#     }
    
#     # Fetch the page
#     response = requests.get(link, headers=headers)
    
#     if response.status_code != 200:
#         print(f"Failed to fetch page: {response.status_code}")
#         return pd.DataFrame()
    
#     # Parse the HTML
#     soup = BeautifulSoup(response.content, "html.parser")

#     # Find the "Totals" heading
#     totals_heading = soup.find("h2", string="Totals")
    
#     if not totals_heading:
#         print("Totals heading not found on the page.")
#         return pd.DataFrame()

#     # Find the table immediately after the "Totals" heading
#     totals_table = totals_heading.find_next("table")

#     if not totals_table:
#         print("Totals table not found.")
#         return pd.DataFrame()

#     # Extract table rows
#     rows = totals_table.find("tbody").find_all("tr")

#     # Lists to store extracted data
#     seasons, ages, threes, three_attempts = [], [], [], []

#     # Initialize season counter
#     season_counter = 1

#     for row in rows:
#         columns = row.find_all("td")

#         if len(columns) < 12:  # Ensure we have enough columns
#             continue  

#         season = season_counter  # 'season' as a counter starting at 1
#         age = columns[0].text.strip()  # 'age'
#         three_pointers = columns[10].text.strip() if len(columns) > 10 else "0"  # '3p'
#         three_attempts_value = columns[11].text.strip() if len(columns) > 11 else "0"  # '3pa'

#         seasons.append(season)
#         ages.append(age)
#         threes.append(three_pointers)
#         three_attempts.append(three_attempts_value)

#         season_counter += 1  # Increment season counter

#     # Create DataFrame with lowercase column names
#     f_three_pointers = pd.DataFrame({
#         "season": seasons, 
#         "age": ages, 
#         "3p": threes,
#         "3pa": three_attempts
#     })

#     # Convert numeric columns to integers
#     f_three_pointers["3p"] = pd.to_numeric(f_three_pointers["3p"], errors="coerce").fillna(0).astype(int)
#     f_three_pointers["3pa"] = pd.to_numeric(f_three_pointers["3pa"], errors="coerce").fillna(0).astype(int)
#     f_three_pointers["age"] = pd.to_numeric(f_three_pointers["age"], errors="coerce").fillna(0).astype(int)

#     # Display as a scrollable table in Jupyter Notebook
#     display(HTML(f_three_pointers.to_html(notebook=True, escape=False)))
    
#     return f_three_pointers

# # Example Usage
# player_link = "https://www.basketball-reference.com/players/c/curryst01.html"  # Stephen Curry's profile
# f_three_pointers = extract_shooting_stats(player_link)
# Out:
# /var/folders/r0/4vr5j1517ggd5nvq86w27hhm0000gn/T/ipykernel_53957/2619089692.py:4: DeprecationWarning:
#
# Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython.display
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>season</th>
#       <th>age</th>
#       <th>3p</th>
#       <th>3pa</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>21</td>
#       <td>166</td>
#       <td>380</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>22</td>
#       <td>151</td>
#       <td>342</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>23</td>
#       <td>55</td>
#       <td>121</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>24</td>
#       <td>272</td>
#       <td>600</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>25</td>
#       <td>261</td>
#       <td>615</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>26</td>
#       <td>286</td>
#       <td>646</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>27</td>
#       <td>402</td>
#       <td>886</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>28</td>
#       <td>324</td>
#       <td>789</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>29</td>
#       <td>212</td>
#       <td>501</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>30</td>
#       <td>354</td>
#       <td>810</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>11</td>
#       <td>31</td>
#       <td>12</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>12</td>
#       <td>32</td>
#       <td>337</td>
#       <td>801</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>13</td>
#       <td>33</td>
#       <td>285</td>
#       <td>750</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>14</td>
#       <td>34</td>
#       <td>273</td>
#       <td>639</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>15</td>
#       <td>35</td>
#       <td>357</td>
#       <td>876</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>16</td>
#       <td>36</td>
#       <td>251</td>
#       <td>630</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# <!-- ## f_top_shooters -->

# %%
# import pandas as pd
# import requests
# from bs4 import BeautifulSoup
# from IPython.core.display import display, HTML

# # Ensure extract_shooting_stats is already defined

# def extract_f_top_shooters(file_path="d_top_shooters.csv"):
#     """
#     Reads player links from d_top_shooters.csv, selects the top 30 players by rank, 
#     and runs extract_shooting_stats on each link.
    
#     Saves the combined results into f_top_shooters.csv.
    
#     Parameters:
#         file_path (str): Path to d_top_shooters.csv.
        
#     Returns:
#         DataFrame with columns ['name', 'rank', 'season', 'age', '3p', '3pa']
#     """
#     # Load player links
#     df_shooters = pd.read_csv(file_path)

#     # Ensure required columns exist
#     if "rank" not in df_shooters.columns or "name" not in df_shooters.columns or "link" not in df_shooters.columns:
#         print("Error: The file must contain 'rank', 'name', and 'link' columns.")
#         return pd.DataFrame()

#     # Process only the top 30 based on rank
#     df_top_30 = df_shooters.nsmallest(30, "rank")

#     all_data = []  # List to store results

#     # Iterate through each player
#     for index, row in df_top_30.iterrows():
#         name, rank, link = row["name"], row["rank"], row["link"]
#         print(f"Processing: {name} (Rank: {rank}) - {index+1}/{len(df_top_30)}")  # Progress tracking

#         # Extract stats
#         player_df = extract_shooting_stats(link)

#         if player_df.empty:
#             print(f"Skipping {name} (No data found)")
#             continue  # Skip if no data

#         # Add player name and rank as first two columns
#         player_df.insert(0, "name", name)
#         player_df.insert(1, "rank", rank)

#         # Store result
#         all_data.append(player_df)

#     # Combine all player data
#     if not all_data:
#         print("No data extracted for any player.")
#         return pd.DataFrame()

#     f_top_shooters_df = pd.concat(all_data, ignore_index=True)

#     # Save the DataFrame
#     f_top_shooters_df.to_csv("f_top_shooters.csv", index=False, encoding="utf-8")

#     # Display as a scrollable table in Jupyter Notebook
#     display(HTML(f_top_shooters_df.to_html(notebook=True, escape=False)))

#     print("Data saved as f_top_shooters.csv")
    
#     return f_top_shooters_df

# # Run the function
# f_top_shooters = extract_f_top_shooters()

# %%
# import pandas as pd
# from IPython.core.display import display, HTML

# # Load f_top_shooters.csv
# f_top_shooters = pd.read_csv("f_top_shooters.csv")

# # Ensure required columns exist
# required_cols = {"name", "rank", "season", "age", "3p", "3pa"}
# if not required_cols.issubset(f_top_shooters.columns):
#     print(f"Error: The file must contain {required_cols} columns.")
# else:
#     # Sort by rank, name, and age before deduplication
#     f_top_shooters.sort_values(by=["rank", "name", "age"], ascending=[True, True, True], inplace=True)

#     # Remove duplicates, keeping only the first row per (name, age) pair
#     f_top_shooters = f_top_shooters.drop_duplicates(subset=["name", "age"], keep="first")

#     # Recalculate season numbers to maintain sequential order
#     f_top_shooters["season"] = f_top_shooters.groupby("name").cumcount() + 1

#     # Recalculate cumulative sums per player
#     f_top_shooters["3p_cum"] = f_top_shooters.groupby("name")["3p"].cumsum()
#     f_top_shooters["3pa_cum"] = f_top_shooters.groupby("name")["3pa"].cumsum()

#     # Save the cleaned DataFrame
#     f_top_shooters.to_csv("f_top_shooters.csv", index=False, encoding="utf-8")

#     # Display as a scrollable table in Jupyter Notebook
#     display(HTML(f_top_shooters.to_html(notebook=True, escape=False)))

#     print("Updated f_top_shooters.csv with deduplicated players and correct cumulative 3P and 3PA.")

# %%
import pandas as pd
import plotly.express as px
import os
from IPython.core.display import display

# Function to generate and display the final cumulative 3P trend chart
def display_final_cumulative_3p_chart(file_path="f_top_shooters.csv", height=600, width=800):
    """
    Reads f_top_shooters.csv and generates the final cumulative 3P trend chart (last frame only).
    
    Displays the chart directly in Jupyter Notebook.
    
    Parameters:
        file_path (str): Path to f_top_shooters.csv.
        height (int): Chart height in pixels.
        width (int): Chart width in pixels.

    Returns:
        None
    """
    # Load data
    if not os.path.exists(file_path):
        print(f"Error: {file_path} not found.")
        return
    
    f_top_shooters = pd.read_csv(file_path)

    # Ensure required columns exist
    required_cols = {"name", "rank", "season", "3p_cum"}
    if not required_cols.issubset(f_top_shooters.columns):
        print(f"Error: The file must contain {required_cols} columns.")
        return

    # Get unique players ordered from rank 30 to rank 1
    players = f_top_shooters.sort_values("rank", ascending=False)["name"].unique()

    # Initialize the final dataset for the last frame
    final_chart_data = pd.DataFrame()

    # Loop through each player in descending rank order (30 → 1)
    for player_name in players:
        # Filter the data for the current player
        player_data = f_top_shooters[f_top_shooters['name'] == player_name]

        if player_data.empty:
            print(f"No data available for {player_name}")
            continue

        # Get the player's full cumulative history (for final frame)
        final_chart_data = pd.concat([final_chart_data, player_data], ignore_index=True)

    # Determine global max for y-axis
    global_max = final_chart_data["3p_cum"].max() + 100

    # Generate the final trend chart
    fig = px.line(final_chart_data, 
                  x="season", 
                  y="3p_cum", 
                  color="name", 
                  template="HorizonAnalytics")

    # Fix x-axis and y-axis labels, ensure labels are clear
    fig.update_layout(
        xaxis=dict(
            title=None, 
            showticklabels=True,
            ticklabelposition="outside",
            tickmode="linear",
            dtick=1  # Ensure only whole numbers appear on x-axis
        ),
        yaxis=dict(
            range=[0, global_max],  
            title=None, 
            showticklabels=True,
            ticklabelposition="outside",
        ),
        margin=dict(l=180, r=40, t=40, b=140),  # Adjust margins for clarity
        showlegend=False,
        height=height,
        width=width,
        plot_bgcolor="rgba(0, 0, 0, 0)",  # Transparent background
        paper_bgcolor="rgba(0, 0, 0, 0)"
    )

    # Display the final frame in Jupyter Notebook
    display(fig)

# Run the function to display the last frame
display_final_cumulative_3p_chart(file_path="f_top_shooters.csv", height=1080, width=1280)
# Out:
# /var/folders/r0/4vr5j1517ggd5nvq86w27hhm0000gn/T/ipykernel_74440/1388604031.py:4: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython.display
#   from IPython.core.display import display, HTML
# Charts saved in: /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2025-03 three_pointers/trend_chart

# %% [markdown]
# <!-- extract text: name, num threes, record
# extract photos:  players -->

# %%
import pandas as pd
import plotly.express as px
import os
from IPython.core.display import display

# Function to generate the final cumulative 3P trend chart
def display_final_cumulative_3p_chart(file_path="f_top_shooters.csv", height=600, width=800, line_width=2):
    """
    Reads f_top_shooters.csv and generates the final cumulative 3P trend chart,
    ensuring each player starts at Season 0 with 3P cumulative = 0.
    
    Displays the chart in Jupyter Notebook (does not save it as a file).

    Parameters:
        file_path (str): Path to f_top_shooters.csv.
        height (int): Chart height in pixels.
        width (int): Chart width in pixels.
        line_width (int): Thickness of the lines in the plot.

    Returns:
        None (displays the figure).
    """
    # Load data
    if not os.path.exists(file_path):
        print(f"Error: {file_path} not found.")
        return
    
    f_top_shooters = pd.read_csv(file_path)

    # Ensure required columns exist
    required_cols = {"name", "rank", "season", "3p_cum"}
    if not required_cols.issubset(f_top_shooters.columns):
        print(f"Error: The file must contain {required_cols} columns.")
        return

    # Create a new DataFrame ensuring every player starts at season 0 with 3p_cum = 0
    adjusted_data = []

    for player_name, group in f_top_shooters.groupby("name"):
        # Create the Season 0 entry
        season_0 = {
            "name": player_name,
            "rank": group["rank"].iloc[0],  # Keep the rank of the player
            "season": 0,
            "3p_cum": 0
        }
        
        # Append Season 0 row, then all other rows for the player
        adjusted_data.append(season_0)
        adjusted_data.extend(group.to_dict(orient="records"))

    # Convert adjusted data back to DataFrame
    f_top_shooters = pd.DataFrame(adjusted_data)

    # Ensure correct ordering: first by rank (descending), then by season (ascending)
    f_top_shooters = f_top_shooters.sort_values(["rank", "season"], ascending=[False, True])

    # Get unique players ordered from rank 30 to rank 1
    players = f_top_shooters["name"].unique()

    # Initialize list to store traces
    traces = []

    # Loop through each player
    for player_name in players:
        # Filter the data for the current player
        player_data = f_top_shooters[f_top_shooters['name'] == player_name]

        if player_data.empty:
            print(f"No data available for {player_name}")
            continue

        # Define line color: Steph Curry in yellow, others in grey
        line_color = "yellow" if player_name == "Stephen Curry" else "lightgrey"

        # Add player trace
        trace = px.line(
            player_data,
            x="season",
            y="3p_cum",
            color_discrete_sequence=[line_color]
        ).data[0]
        
        # Set line width
        trace.line.width = line_width
        traces.append(trace)

    # Create the final figure with all traces
    fig = px.line(template="HorizonAnalytics")
    for trace in traces:
        fig.add_trace(trace)

    # Configure layout settings
    fig.update_layout(
        xaxis=dict(
            title=None,
            showticklabels=True,
            ticklabelposition="outside",
            tickmode="linear",
            dtick=1  # Ensure only whole numbers appear on x-axis
        ),
        yaxis=dict(
            title=None,
            showticklabels=True,
            ticklabelposition="outside",
        ),
        margin=dict(l=180, r=40, t=40, b=140),  # Increase margins to prevent axis label cutoff
        showlegend=False,
        height=height,
        width=width,
        plot_bgcolor='rgba(0, 0, 0, 0)',  # Transparent background
        paper_bgcolor='rgba(0, 0, 0, 0)'
    )

    # Display the final chart
    display(fig)

# Run the function to display the last frame
display_final_cumulative_3p_chart(file_path="f_top_shooters.csv", height=1080, width=1920, line_width=12)
# Out:
# /var/folders/r0/4vr5j1517ggd5nvq86w27hhm0000gn/T/ipykernel_74440/4170886114.py:4: DeprecationWarning:
#
# Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython.display

# %% [markdown]
# <!-- Photos -->

# %%
import os
import requests
import pandas as pd

# Define save location
output_dir = "/Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2025-03 three_pointers/player_images"
os.makedirs(output_dir, exist_ok=True)

# Manually provided NBA stats links for top 30 shooters
nba_stats_links = [
    "https://www.nba.com/stats/player/201939/traditional",
    "https://www.nba.com/stats/player/201935/traditional",
    "https://www.nba.com/stats/player/951/traditional",
    "https://www.nba.com/stats/player/203081/traditional",
    "https://www.nba.com/stats/player/202691/traditional",
    "https://www.nba.com/stats/player/397/traditional",
    "https://www.nba.com/stats/player/2544/traditional",
    "https://www.nba.com/stats/player/2594/traditional",
    "https://www.nba.com/stats/player/202331/traditional",
    "https://www.nba.com/stats/player/1713/traditional",
    "https://www.nba.com/stats/player/1891/traditional",
    "https://www.nba.com/stats/player/2037/traditional",
    "https://www.nba.com/stats/player/200768/traditional",
    "https://www.nba.com/stats/player/201142/traditional",
    "https://www.nba.com/stats/player/1718/traditional",
    "https://www.nba.com/stats/player/1627741/traditional",
    "https://www.nba.com/stats/player/201569/traditional",
    "https://www.nba.com/stats/player/467/traditional",
    "https://www.nba.com/stats/player/1717/traditional",
    "https://www.nba.com/stats/player/2207/traditional",
    "https://www.nba.com/stats/player/203468/traditional",
    "https://www.nba.com/stats/player/200755/traditional",
    "https://www.nba.com/stats/player/2747/traditional",
    "https://www.nba.com/stats/player/201144/traditional",
    "https://www.nba.com/stats/player/202681/traditional",
    "https://www.nba.com/stats/player/202083/traditional",
    "https://www.nba.com/stats/player/101108/traditional",
    "https://www.nba.com/stats/player/1497/traditional",
    "https://www.nba.com/stats/player/977/traditional",
    "https://www.nba.com/stats/player/203501/traditional"
]

# Read d_top_shooters.csv and get top 30 players (to match names to links)
file_path = "d_top_shooters.csv"
df_shooters = pd.read_csv(file_path)
df_top_30 = df_shooters.nsmallest(30, "rank")

# Ensure we have exactly 30 links
if len(df_top_30) != len(nba_stats_links):
    print("Error: Mismatch between top 30 players and provided NBA links.")
    exit()

# Function to download an image
def download_image(url, path):
    if url:
        headers = {"User-Agent": "Mozilla/5.0"}
        for attempt in range(3):  # Retry up to 3 times
            print(f"Downloading (attempt {attempt+1}) {url} -> {path}")
            response = requests.get(url, headers=headers, allow_redirects=True, stream=True)
            if response.status_code == 200:
                with open(path, "wb") as file:
                    for chunk in response.iter_content(1024):
                        file.write(chunk)
                print(f"✅ Saved: {path}")
                return
            else:
                print(f"❌ Failed (attempt {attempt+1}) with status code: {response.status_code}")
        print(f"🚨 Skipping: {url} after 3 failed attempts")

# Process each player
for index, (nba_link, row) in enumerate(zip(nba_stats_links, df_top_30.itertuples()), start=1):
    name = row.name
    rank = row.rank
    player_id = nba_link.split("/")[-2]  # Extracts the player ID from the URL

    # Construct the headshot URL
    image_url = f"https://cdn.nba.com/headshots/nba/latest/1040x760/{player_id}.png"

    # Save as {rank}.jpg (e.g., 1.jpg, 2.jpg, ..., 30.jpg)
    file_path = os.path.join(output_dir, f"{rank}.jpg")
    download_image(image_url, file_path)

print("All available images downloaded successfully!")

# %%
import os
import shutil
import pandas as pd
from PIL import Image

# Directories
base_dir = "/Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2025-03 three_pointers"
source_dir = os.path.join(base_dir, "player_images")  # Where headshots are stored
output_dir = os.path.join(base_dir, "player_frames")  # Where duplicated frames will be stored

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Load data
f_top_shooters_path = "f_top_shooters.csv"
d_top_shooters_path = "d_top_shooters.csv"

if not os.path.exists(f_top_shooters_path) or not os.path.exists(d_top_shooters_path):
    print("Error: Missing required CSV files.")
    exit()

df_shooters = pd.read_csv(d_top_shooters_path)  # Original rankings
df_top_shooters = pd.read_csv(f_top_shooters_path)  # Expanded season data

# Reverse the order: Start from rank 30, moving to rank 1
df_top_shooters = df_top_shooters.iloc[::-1].reset_index(drop=True)

# Create a mapping: {name → rank}
name_to_rank = df_shooters.set_index("name")["rank"].to_dict()

# Iterate over f_top_shooters in reversed order
for index, row in enumerate(df_top_shooters.itertuples(), start=1):
    name = row.name
    rank = name_to_rank.get(name)

    if rank is None:
        print(f"❌ No rank found for {name}, skipping.")
        continue

    # Special case for Jason Kidd (rank 18, uses .png)
    if rank == 18:
        source_image = os.path.join(source_dir, "18.png")
    else:
        source_image = os.path.join(source_dir, f"{rank}.jpg")

    # Destination image path (000001.png, 000002.png, ...)
    dest_image = os.path.join(output_dir, f"{index:06d}.png")

    # Convert and save as PNG
    if os.path.exists(source_image):
        try:
            img = Image.open(source_image)
            img.save(dest_image, "PNG")  # Convert to PNG format
            print(f"✅ Converted & saved: {dest_image}")
        except Exception as e:
            print(f"❌ Error converting {source_image}: {e}")
    else:
        print(f"❌ Missing headshot for {name} ({source_image})")

print("✅ All player frames saved as PNG successfully!")

# %% [markdown]
# ## Name Frames

# %%
from PIL import Image, ImageDraw, ImageFont
import pandas as pd
import os

# Directories
base_dir = "/Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2025-03 three_pointers"
output_dir = os.path.join(base_dir, "name_frames")  # Folder for name frames

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Function to generate name frames for each row in f_top_shooters.csv
def generate_player_name_frames(file_path="f_top_shooters.csv", height=720, width=1280, 
                                output_dir=output_dir, font_size=51, font_type="ExtraBold", 
                                font_color=(255, 255, 255), font_outline_width=3, 
                                font_outline_color=(0, 0, 0)):
    """
    Reads f_top_shooters.csv, extracts names & ranks (matching row count), and generates PNG frames.
    Format: 'Rank. Name' (e.g., '30. Tim Hardaway Jr.').
    Saves in reverse order (30th-ranked player first, 1st-ranked player last).
    
    Parameters:
        file_path (str): Path to f_top_shooters.csv.
        height (int): Image height in pixels.
        width (int): Image width in pixels.
        output_dir (str): Folder to save output frames.
        font_size (int): Size of the text font.
        font_type (str): Font weight (e.g., "Regular", "Bold", "ExtraBold").
        font_color (tuple): RGB color of the text (default: white).
        font_outline_width (int): Thickness of text outline.
        font_outline_color (tuple): RGB color of text outline (default: black).
    """
    # Load player data
    if not os.path.exists(file_path):
        print(f"Error: {file_path} not found.")
        return
    
    df_top_shooters = pd.read_csv(file_path)

    # Ensure required columns exist
    if "name" not in df_top_shooters.columns or "rank" not in df_top_shooters.columns:
        print("Error: f_top_shooters.csv must contain 'name' and 'rank' columns.")
        return

    # Sort by rank in **ascending** order (1 → 30) and keep full row count
    df_top_shooters = df_top_shooters.sort_values("rank", ascending=True)

    # Extract names & ranks while keeping row order, then **REVERSE the full dataset**
    player_labels = [f"{rank}. {name.upper()}" for rank, name in zip(df_top_shooters["rank"], df_top_shooters["name"])][::-1]

    # Define Montserrat font path
    font_path = os.path.join("..", "Montserrat", f"Montserrat-{font_type}.ttf")

    # Try to load the selected font, fallback to default if missing
    try:
        font = ImageFont.truetype(font_path, font_size)
    except IOError:
        print(f"Montserrat font '{font_type}' not found. Using default font.")
        font = ImageFont.load_default()

    # Generate a frame for each row in f_top_shooters (duplicating names accordingly)
    for frame_index, player_label in enumerate(player_labels, start=1):
        # Create an empty image with transparent background
        img = Image.new("RGBA", (width, height), color=(0, 0, 0, 0))
        draw = ImageDraw.Draw(img)

        # Position the text at the center
        text_bbox = draw.textbbox((0, 0), player_label, font=font)
        text_width, text_height = text_bbox[2] - text_bbox[0], text_bbox[3] - text_bbox[1]
        text_position = ((width - text_width) // 2, (height - text_height) // 2)

        # Add outline effect
        if font_outline_width > 0:
            for dx in range(-font_outline_width, font_outline_width + 1):
                for dy in range(-font_outline_width, font_outline_width + 1):
                    if dx != 0 or dy != 0:  # Skip center position
                        draw.text((text_position[0] + dx, text_position[1] + dy), player_label, font=font, fill=font_outline_color)

        # Draw the main text
        draw.text(text_position, player_label, font=font, fill=font_color)

        # Construct file name (e.g., 0001.png, 0002.png) in **REVERSE order**
        file_name = f"{frame_index:06d}.png"
        file_path = os.path.join(output_dir, file_name)

        # Save the image
        img.save(file_path, "PNG")

        print(f"✅ Saved frame for: {player_label} → {file_name}")

    print(f"✅ Name frames saved in: {output_dir}")

# Run the function with Montserrat ExtraBold
generate_player_name_frames(file_path="f_top_shooters.csv", height=720, width=1280, 
                            font_size=51, font_type="ExtraBold", 
                            font_color=(255, 255, 255), font_outline_width=3, 
                            font_outline_color=(0, 0, 0))
# Out:
# ✅ Saved frame for: 30. TIM HARDAWAY JR. → 000001.png
# ✅ Saved frame for: 30. TIM HARDAWAY JR. → 000002.png
# ✅ Saved frame for: 30. TIM HARDAWAY JR. → 000003.png
# ✅ Saved frame for: 30. TIM HARDAWAY JR. → 000004.png
# ✅ Saved frame for: 30. TIM HARDAWAY JR. → 000005.png
# ✅ Saved frame for: 30. TIM HARDAWAY JR. → 000006.png
# ✅ Saved frame for: 30. TIM HARDAWAY JR. → 000007.png
# ✅ Saved frame for: 30. TIM HARDAWAY JR. → 000008.png
# ✅ Saved frame for: 30. TIM HARDAWAY JR. → 000009.png
# ✅ Saved frame for: 30. TIM HARDAWAY JR. → 000010.png
# ✅ Saved frame for: 30. TIM HARDAWAY JR. → 000011.png
# ✅ Saved frame for: 30. TIM HARDAWAY JR. → 000012.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000013.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000014.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000015.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000016.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000017.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000018.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000019.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000020.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000021.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000022.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000023.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000024.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000025.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000026.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000027.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000028.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000029.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000030.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000031.png
# ✅ Saved frame for: 29. KOBE BRYANT → 000032.png
# ✅ Saved frame for: 28. CHAUNCEY BILLUPS → 000033.png
# ✅ Saved frame for: 28. CHAUNCEY BILLUPS → 000034.png
# ✅ Saved frame for: 28. CHAUNCEY BILLUPS → 000035.png
# ✅ Saved frame for: 28. CHAUNCEY BILLUPS → 000036.png
# ✅ Saved frame for: 28. CHAUNCEY BILLUPS → 000037.png
# ✅ Saved frame for: 28. CHAUNCEY BILLUPS → 000038.png
# ✅ Saved frame for: 28. CHAUNCEY BILLUPS → 000039.png
# ✅ Saved frame for: 28. CHAUNCEY BILLUPS → 000040.png
# ✅ Saved frame for: 28. CHAUNCEY BILLUPS → 000041.png
# ✅ Saved frame for: 28. CHAUNCEY BILLUPS → 000042.png
# ✅ Saved frame for: 28. CHAUNCEY BILLUPS → 000043.png
# ✅ Saved frame for: 28. CHAUNCEY BILLUPS → 000044.png
# ✅ Saved frame for: 28. CHAUNCEY BILLUPS → 000045.png
# ✅ Saved frame for: 28. CHAUNCEY BILLUPS → 000046.png
# ✅ Saved frame for: 28. CHAUNCEY BILLUPS → 000047.png
# ✅ Saved frame for: 28. CHAUNCEY BILLUPS → 000048.png
# ✅ Saved frame for: 28. CHAUNCEY BILLUPS → 000049.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000050.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000051.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000052.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000053.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000054.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000055.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000056.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000057.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000058.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000059.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000060.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000061.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000062.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000063.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000064.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000065.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000066.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000067.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000068.png
# ✅ Saved frame for: 27. CHRIS PAUL → 000069.png
# ✅ Saved frame for: 26. WESLEY MATTHEWS → 000070.png
# ✅ Saved frame for: 26. WESLEY MATTHEWS → 000071.png
# ✅ Saved frame for: 26. WESLEY MATTHEWS → 000072.png
# ✅ Saved frame for: 26. WESLEY MATTHEWS → 000073.png
# ✅ Saved frame for: 26. WESLEY MATTHEWS → 000074.png
# ✅ Saved frame for: 26. WESLEY MATTHEWS → 000075.png
# ✅ Saved frame for: 26. WESLEY MATTHEWS → 000076.png
# ✅ Saved frame for: 26. WESLEY MATTHEWS → 000077.png
# ✅ Saved frame for: 26. WESLEY MATTHEWS → 000078.png
# ✅ Saved frame for: 26. WESLEY MATTHEWS → 000079.png
# ✅ Saved frame for: 26. WESLEY MATTHEWS → 000080.png
# ✅ Saved frame for: 26. WESLEY MATTHEWS → 000081.png
# ✅ Saved frame for: 26. WESLEY MATTHEWS → 000082.png
# ✅ Saved frame for: 26. WESLEY MATTHEWS → 000083.png
# ✅ Saved frame for: 26. WESLEY MATTHEWS → 000084.png
# ✅ Saved frame for: 25. KYRIE IRVING → 000085.png
# ✅ Saved frame for: 25. KYRIE IRVING → 000086.png
# ✅ Saved frame for: 25. KYRIE IRVING → 000087.png
# ✅ Saved frame for: 25. KYRIE IRVING → 000088.png
# ✅ Saved frame for: 25. KYRIE IRVING → 000089.png
# ✅ Saved frame for: 25. KYRIE IRVING → 000090.png
# ✅ Saved frame for: 25. KYRIE IRVING → 000091.png
# ✅ Saved frame for: 25. KYRIE IRVING → 000092.png
# ✅ Saved frame for: 25. KYRIE IRVING → 000093.png
# ✅ Saved frame for: 25. KYRIE IRVING → 000094.png
# ✅ Saved frame for: 25. KYRIE IRVING → 000095.png
# ✅ Saved frame for: 25. KYRIE IRVING → 000096.png
# ✅ Saved frame for: 25. KYRIE IRVING → 000097.png
# ✅ Saved frame for: 25. KYRIE IRVING → 000098.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000099.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000100.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000101.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000102.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000103.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000104.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000105.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000106.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000107.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000108.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000109.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000110.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000111.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000112.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000113.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000114.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000115.png
# ✅ Saved frame for: 24. MIKE CONLEY → 000116.png
# ✅ Saved frame for: 23. J.R. SMITH → 000117.png
# ✅ Saved frame for: 23. J.R. SMITH → 000118.png
# ✅ Saved frame for: 23. J.R. SMITH → 000119.png
# ✅ Saved frame for: 23. J.R. SMITH → 000120.png
# ✅ Saved frame for: 23. J.R. SMITH → 000121.png
# ✅ Saved frame for: 23. J.R. SMITH → 000122.png
# ✅ Saved frame for: 23. J.R. SMITH → 000123.png
# ✅ Saved frame for: 23. J.R. SMITH → 000124.png
# ✅ Saved frame for: 23. J.R. SMITH → 000125.png
# ✅ Saved frame for: 23. J.R. SMITH → 000126.png
# ✅ Saved frame for: 23. J.R. SMITH → 000127.png
# ✅ Saved frame for: 23. J.R. SMITH → 000128.png
# ✅ Saved frame for: 23. J.R. SMITH → 000129.png
# ✅ Saved frame for: 23. J.R. SMITH → 000130.png
# ✅ Saved frame for: 23. J.R. SMITH → 000131.png
# ✅ Saved frame for: 23. J.R. SMITH → 000132.png
# ✅ Saved frame for: 22. JJ REDICK → 000133.png
# ✅ Saved frame for: 22. JJ REDICK → 000134.png
# ✅ Saved frame for: 22. JJ REDICK → 000135.png
# ✅ Saved frame for: 22. JJ REDICK → 000136.png
# ✅ Saved frame for: 22. JJ REDICK → 000137.png
# ✅ Saved frame for: 22. JJ REDICK → 000138.png
# ✅ Saved frame for: 22. JJ REDICK → 000139.png
# ✅ Saved frame for: 22. JJ REDICK → 000140.png
# ✅ Saved frame for: 22. JJ REDICK → 000141.png
# ✅ Saved frame for: 22. JJ REDICK → 000142.png
# ✅ Saved frame for: 22. JJ REDICK → 000143.png
# ✅ Saved frame for: 22. JJ REDICK → 000144.png
# ✅ Saved frame for: 22. JJ REDICK → 000145.png
# ✅ Saved frame for: 22. JJ REDICK → 000146.png
# ✅ Saved frame for: 22. JJ REDICK → 000147.png
# ✅ Saved frame for: 21. CJ MCCOLLUM → 000148.png
# ✅ Saved frame for: 21. CJ MCCOLLUM → 000149.png
# ✅ Saved frame for: 21. CJ MCCOLLUM → 000150.png
# ✅ Saved frame for: 21. CJ MCCOLLUM → 000151.png
# ✅ Saved frame for: 21. CJ MCCOLLUM → 000152.png
# ✅ Saved frame for: 21. CJ MCCOLLUM → 000153.png
# ✅ Saved frame for: 21. CJ MCCOLLUM → 000154.png
# ✅ Saved frame for: 21. CJ MCCOLLUM → 000155.png
# ✅ Saved frame for: 21. CJ MCCOLLUM → 000156.png
# ✅ Saved frame for: 21. CJ MCCOLLUM → 000157.png
# ✅ Saved frame for: 21. CJ MCCOLLUM → 000158.png
# ✅ Saved frame for: 21. CJ MCCOLLUM → 000159.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000160.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000161.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000162.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000163.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000164.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000165.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000166.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000167.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000168.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000169.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000170.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000171.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000172.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000173.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000174.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000175.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000176.png
# ✅ Saved frame for: 20. JOE JOHNSON → 000177.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000178.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000179.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000180.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000181.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000182.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000183.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000184.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000185.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000186.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000187.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000188.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000189.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000190.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000191.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000192.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000193.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000194.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000195.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000196.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000197.png
# ✅ Saved frame for: 19. DIRK NOWITZKI → 000198.png
# ✅ Saved frame for: 18. JASON KIDD → 000199.png
# ✅ Saved frame for: 18. JASON KIDD → 000200.png
# ✅ Saved frame for: 18. JASON KIDD → 000201.png
# ✅ Saved frame for: 18. JASON KIDD → 000202.png
# ✅ Saved frame for: 18. JASON KIDD → 000203.png
# ✅ Saved frame for: 18. JASON KIDD → 000204.png
# ✅ Saved frame for: 18. JASON KIDD → 000205.png
# ✅ Saved frame for: 18. JASON KIDD → 000206.png
# ✅ Saved frame for: 18. JASON KIDD → 000207.png
# ✅ Saved frame for: 18. JASON KIDD → 000208.png
# ✅ Saved frame for: 18. JASON KIDD → 000209.png
# ✅ Saved frame for: 18. JASON KIDD → 000210.png
# ✅ Saved frame for: 18. JASON KIDD → 000211.png
# ✅ Saved frame for: 18. JASON KIDD → 000212.png
# ✅ Saved frame for: 18. JASON KIDD → 000213.png
# ✅ Saved frame for: 18. JASON KIDD → 000214.png
# ✅ Saved frame for: 18. JASON KIDD → 000215.png
# ✅ Saved frame for: 18. JASON KIDD → 000216.png
# ✅ Saved frame for: 18. JASON KIDD → 000217.png
# ✅ Saved frame for: 17. ERIC GORDON → 000218.png
# ✅ Saved frame for: 17. ERIC GORDON → 000219.png
# ✅ Saved frame for: 17. ERIC GORDON → 000220.png
# ✅ Saved frame for: 17. ERIC GORDON → 000221.png
# ✅ Saved frame for: 17. ERIC GORDON → 000222.png
# ✅ Saved frame for: 17. ERIC GORDON → 000223.png
# ✅ Saved frame for: 17. ERIC GORDON → 000224.png
# ✅ Saved frame for: 17. ERIC GORDON → 000225.png
# ✅ Saved frame for: 17. ERIC GORDON → 000226.png
# ✅ Saved frame for: 17. ERIC GORDON → 000227.png
# ✅ Saved frame for: 17. ERIC GORDON → 000228.png
# ✅ Saved frame for: 17. ERIC GORDON → 000229.png
# ✅ Saved frame for: 17. ERIC GORDON → 000230.png
# ✅ Saved frame for: 17. ERIC GORDON → 000231.png
# ✅ Saved frame for: 17. ERIC GORDON → 000232.png
# ✅ Saved frame for: 17. ERIC GORDON → 000233.png
# ✅ Saved frame for: 17. ERIC GORDON → 000234.png
# ✅ Saved frame for: 16. BUDDY HIELD → 000235.png
# ✅ Saved frame for: 16. BUDDY HIELD → 000236.png
# ✅ Saved frame for: 16. BUDDY HIELD → 000237.png
# ✅ Saved frame for: 16. BUDDY HIELD → 000238.png
# ✅ Saved frame for: 16. BUDDY HIELD → 000239.png
# ✅ Saved frame for: 16. BUDDY HIELD → 000240.png
# ✅ Saved frame for: 16. BUDDY HIELD → 000241.png
# ✅ Saved frame for: 16. BUDDY HIELD → 000242.png
# ✅ Saved frame for: 16. BUDDY HIELD → 000243.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000244.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000245.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000246.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000247.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000248.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000249.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000250.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000251.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000252.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000253.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000254.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000255.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000256.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000257.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000258.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000259.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000260.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000261.png
# ✅ Saved frame for: 15. PAUL PIERCE → 000262.png
# ✅ Saved frame for: 14. KEVIN DURANT → 000263.png
# ✅ Saved frame for: 14. KEVIN DURANT → 000264.png
# ✅ Saved frame for: 14. KEVIN DURANT → 000265.png
# ✅ Saved frame for: 14. KEVIN DURANT → 000266.png
# ✅ Saved frame for: 14. KEVIN DURANT → 000267.png
# ✅ Saved frame for: 14. KEVIN DURANT → 000268.png
# ✅ Saved frame for: 14. KEVIN DURANT → 000269.png
# ✅ Saved frame for: 14. KEVIN DURANT → 000270.png
# ✅ Saved frame for: 14. KEVIN DURANT → 000271.png
# ✅ Saved frame for: 14. KEVIN DURANT → 000272.png
# ✅ Saved frame for: 14. KEVIN DURANT → 000273.png
# ✅ Saved frame for: 14. KEVIN DURANT → 000274.png
# ✅ Saved frame for: 14. KEVIN DURANT → 000275.png
# ✅ Saved frame for: 14. KEVIN DURANT → 000276.png
# ✅ Saved frame for: 14. KEVIN DURANT → 000277.png
# ✅ Saved frame for: 14. KEVIN DURANT → 000278.png
# ✅ Saved frame for: 14. KEVIN DURANT → 000279.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000280.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000281.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000282.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000283.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000284.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000285.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000286.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000287.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000288.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000289.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000290.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000291.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000292.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000293.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000294.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000295.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000296.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000297.png
# ✅ Saved frame for: 13. KYLE LOWRY → 000298.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000299.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000300.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000301.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000302.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000303.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000304.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000305.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000306.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000307.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000308.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000309.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000310.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000311.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000312.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000313.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000314.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000315.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000316.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000317.png
# ✅ Saved frame for: 12. JAMAL CRAWFORD → 000318.png
# ✅ Saved frame for: 11. JASON TERRY → 000319.png
# ✅ Saved frame for: 11. JASON TERRY → 000320.png
# ✅ Saved frame for: 11. JASON TERRY → 000321.png
# ✅ Saved frame for: 11. JASON TERRY → 000322.png
# ✅ Saved frame for: 11. JASON TERRY → 000323.png
# ✅ Saved frame for: 11. JASON TERRY → 000324.png
# ✅ Saved frame for: 11. JASON TERRY → 000325.png
# ✅ Saved frame for: 11. JASON TERRY → 000326.png
# ✅ Saved frame for: 11. JASON TERRY → 000327.png
# ✅ Saved frame for: 11. JASON TERRY → 000328.png
# ✅ Saved frame for: 11. JASON TERRY → 000329.png
# ✅ Saved frame for: 11. JASON TERRY → 000330.png
# ✅ Saved frame for: 11. JASON TERRY → 000331.png
# ✅ Saved frame for: 11. JASON TERRY → 000332.png
# ✅ Saved frame for: 11. JASON TERRY → 000333.png
# ✅ Saved frame for: 11. JASON TERRY → 000334.png
# ✅ Saved frame for: 11. JASON TERRY → 000335.png
# ✅ Saved frame for: 11. JASON TERRY → 000336.png
# ✅ Saved frame for: 11. JASON TERRY → 000337.png
# ✅ Saved frame for: 10. VINCE CARTER → 000338.png
# ✅ Saved frame for: 10. VINCE CARTER → 000339.png
# ✅ Saved frame for: 10. VINCE CARTER → 000340.png
# ✅ Saved frame for: 10. VINCE CARTER → 000341.png
# ✅ Saved frame for: 10. VINCE CARTER → 000342.png
# ✅ Saved frame for: 10. VINCE CARTER → 000343.png
# ✅ Saved frame for: 10. VINCE CARTER → 000344.png
# ✅ Saved frame for: 10. VINCE CARTER → 000345.png
# ✅ Saved frame for: 10. VINCE CARTER → 000346.png
# ✅ Saved frame for: 10. VINCE CARTER → 000347.png
# ✅ Saved frame for: 10. VINCE CARTER → 000348.png
# ✅ Saved frame for: 10. VINCE CARTER → 000349.png
# ✅ Saved frame for: 10. VINCE CARTER → 000350.png
# ✅ Saved frame for: 10. VINCE CARTER → 000351.png
# ✅ Saved frame for: 10. VINCE CARTER → 000352.png
# ✅ Saved frame for: 10. VINCE CARTER → 000353.png
# ✅ Saved frame for: 10. VINCE CARTER → 000354.png
# ✅ Saved frame for: 10. VINCE CARTER → 000355.png
# ✅ Saved frame for: 10. VINCE CARTER → 000356.png
# ✅ Saved frame for: 10. VINCE CARTER → 000357.png
# ✅ Saved frame for: 10. VINCE CARTER → 000358.png
# ✅ Saved frame for: 10. VINCE CARTER → 000359.png
# ✅ Saved frame for: 9. PAUL GEORGE → 000360.png
# ✅ Saved frame for: 9. PAUL GEORGE → 000361.png
# ✅ Saved frame for: 9. PAUL GEORGE → 000362.png
# ✅ Saved frame for: 9. PAUL GEORGE → 000363.png
# ✅ Saved frame for: 9. PAUL GEORGE → 000364.png
# ✅ Saved frame for: 9. PAUL GEORGE → 000365.png
# ✅ Saved frame for: 9. PAUL GEORGE → 000366.png
# ✅ Saved frame for: 9. PAUL GEORGE → 000367.png
# ✅ Saved frame for: 9. PAUL GEORGE → 000368.png
# ✅ Saved frame for: 9. PAUL GEORGE → 000369.png
# ✅ Saved frame for: 9. PAUL GEORGE → 000370.png
# ✅ Saved frame for: 9. PAUL GEORGE → 000371.png
# ✅ Saved frame for: 9. PAUL GEORGE → 000372.png
# ✅ Saved frame for: 9. PAUL GEORGE → 000373.png
# ✅ Saved frame for: 9. PAUL GEORGE → 000374.png
# ✅ Saved frame for: 8. KYLE KORVER → 000375.png
# ✅ Saved frame for: 8. KYLE KORVER → 000376.png
# ✅ Saved frame for: 8. KYLE KORVER → 000377.png
# ✅ Saved frame for: 8. KYLE KORVER → 000378.png
# ✅ Saved frame for: 8. KYLE KORVER → 000379.png
# ✅ Saved frame for: 8. KYLE KORVER → 000380.png
# ✅ Saved frame for: 8. KYLE KORVER → 000381.png
# ✅ Saved frame for: 8. KYLE KORVER → 000382.png
# ✅ Saved frame for: 8. KYLE KORVER → 000383.png
# ✅ Saved frame for: 8. KYLE KORVER → 000384.png
# ✅ Saved frame for: 8. KYLE KORVER → 000385.png
# ✅ Saved frame for: 8. KYLE KORVER → 000386.png
# ✅ Saved frame for: 8. KYLE KORVER → 000387.png
# ✅ Saved frame for: 8. KYLE KORVER → 000388.png
# ✅ Saved frame for: 8. KYLE KORVER → 000389.png
# ✅ Saved frame for: 8. KYLE KORVER → 000390.png
# ✅ Saved frame for: 8. KYLE KORVER → 000391.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000392.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000393.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000394.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000395.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000396.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000397.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000398.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000399.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000400.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000401.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000402.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000403.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000404.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000405.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000406.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000407.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000408.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000409.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000410.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000411.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000412.png
# ✅ Saved frame for: 7. LEBRON JAMES → 000413.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000414.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000415.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000416.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000417.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000418.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000419.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000420.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000421.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000422.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000423.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000424.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000425.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000426.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000427.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000428.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000429.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000430.png
# ✅ Saved frame for: 6. REGGIE MILLER → 000431.png
# ✅ Saved frame for: 5. KLAY THOMPSON → 000432.png
# ✅ Saved frame for: 5. KLAY THOMPSON → 000433.png
# ✅ Saved frame for: 5. KLAY THOMPSON → 000434.png
# ✅ Saved frame for: 5. KLAY THOMPSON → 000435.png
# ✅ Saved frame for: 5. KLAY THOMPSON → 000436.png
# ✅ Saved frame for: 5. KLAY THOMPSON → 000437.png
# ✅ Saved frame for: 5. KLAY THOMPSON → 000438.png
# ✅ Saved frame for: 5. KLAY THOMPSON → 000439.png
# ✅ Saved frame for: 5. KLAY THOMPSON → 000440.png
# ✅ Saved frame for: 5. KLAY THOMPSON → 000441.png
# ✅ Saved frame for: 5. KLAY THOMPSON → 000442.png
# ✅ Saved frame for: 5. KLAY THOMPSON → 000443.png
# ✅ Saved frame for: 4. DAMIAN LILLARD → 000444.png
# ✅ Saved frame for: 4. DAMIAN LILLARD → 000445.png
# ✅ Saved frame for: 4. DAMIAN LILLARD → 000446.png
# ✅ Saved frame for: 4. DAMIAN LILLARD → 000447.png
# ✅ Saved frame for: 4. DAMIAN LILLARD → 000448.png
# ✅ Saved frame for: 4. DAMIAN LILLARD → 000449.png
# ✅ Saved frame for: 4. DAMIAN LILLARD → 000450.png
# ✅ Saved frame for: 4. DAMIAN LILLARD → 000451.png
# ✅ Saved frame for: 4. DAMIAN LILLARD → 000452.png
# ✅ Saved frame for: 4. DAMIAN LILLARD → 000453.png
# ✅ Saved frame for: 4. DAMIAN LILLARD → 000454.png
# ✅ Saved frame for: 4. DAMIAN LILLARD → 000455.png
# ✅ Saved frame for: 4. DAMIAN LILLARD → 000456.png
# ✅ Saved frame for: 3. RAY ALLEN → 000457.png
# ✅ Saved frame for: 3. RAY ALLEN → 000458.png
# ✅ Saved frame for: 3. RAY ALLEN → 000459.png
# ✅ Saved frame for: 3. RAY ALLEN → 000460.png
# ✅ Saved frame for: 3. RAY ALLEN → 000461.png
# ✅ Saved frame for: 3. RAY ALLEN → 000462.png
# ✅ Saved frame for: 3. RAY ALLEN → 000463.png
# ✅ Saved frame for: 3. RAY ALLEN → 000464.png
# ✅ Saved frame for: 3. RAY ALLEN → 000465.png
# ✅ Saved frame for: 3. RAY ALLEN → 000466.png
# ✅ Saved frame for: 3. RAY ALLEN → 000467.png
# ✅ Saved frame for: 3. RAY ALLEN → 000468.png
# ✅ Saved frame for: 3. RAY ALLEN → 000469.png
# ✅ Saved frame for: 3. RAY ALLEN → 000470.png
# ✅ Saved frame for: 3. RAY ALLEN → 000471.png
# ✅ Saved frame for: 3. RAY ALLEN → 000472.png
# ✅ Saved frame for: 3. RAY ALLEN → 000473.png
# ✅ Saved frame for: 3. RAY ALLEN → 000474.png
# ✅ Saved frame for: 2. JAMES HARDEN → 000475.png
# ✅ Saved frame for: 2. JAMES HARDEN → 000476.png
# ✅ Saved frame for: 2. JAMES HARDEN → 000477.png
# ✅ Saved frame for: 2. JAMES HARDEN → 000478.png
# ✅ Saved frame for: 2. JAMES HARDEN → 000479.png
# ✅ Saved frame for: 2. JAMES HARDEN → 000480.png
# ✅ Saved frame for: 2. JAMES HARDEN → 000481.png
# ✅ Saved frame for: 2. JAMES HARDEN → 000482.png
# ✅ Saved frame for: 2. JAMES HARDEN → 000483.png
# ✅ Saved frame for: 2. JAMES HARDEN → 000484.png
# ✅ Saved frame for: 2. JAMES HARDEN → 000485.png
# ✅ Saved frame for: 2. JAMES HARDEN → 000486.png
# ✅ Saved frame for: 2. JAMES HARDEN → 000487.png
# ✅ Saved frame for: 2. JAMES HARDEN → 000488.png
# ✅ Saved frame for: 2. JAMES HARDEN → 000489.png
# ✅ Saved frame for: 2. JAMES HARDEN → 000490.png
# ✅ Saved frame for: 1. STEPHEN CURRY → 000491.png
# ✅ Saved frame for: 1. STEPHEN CURRY → 000492.png
# ✅ Saved frame for: 1. STEPHEN CURRY → 000493.png
# ✅ Saved frame for: 1. STEPHEN CURRY → 000494.png
# ✅ Saved frame for: 1. STEPHEN CURRY → 000495.png
# ✅ Saved frame for: 1. STEPHEN CURRY → 000496.png
# ✅ Saved frame for: 1. STEPHEN CURRY → 000497.png
# ✅ Saved frame for: 1. STEPHEN CURRY → 000498.png
# ✅ Saved frame for: 1. STEPHEN CURRY → 000499.png
# ✅ Saved frame for: 1. STEPHEN CURRY → 000500.png
# ✅ Saved frame for: 1. STEPHEN CURRY → 000501.png
# ✅ Saved frame for: 1. STEPHEN CURRY → 000502.png
# ✅ Saved frame for: 1. STEPHEN CURRY → 000503.png
# ✅ Saved frame for: 1. STEPHEN CURRY → 000504.png
# ✅ Saved frame for: 1. STEPHEN CURRY → 000505.png
# ✅ Saved frame for: 1. STEPHEN CURRY → 000506.png
# ✅ Name frames saved in: /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2025-03 three_pointers/name_frames

# %% [markdown]
# ## Text

# %%
from PIL import Image, ImageDraw, ImageFont
import pandas as pd
import os

# Function to generate and save individual frames displaying Season, Total 3PM, and Record
def generate_text_frames(file_path="f_top_shooters.csv", height=720, width=1280, 
                         output_dir="/Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2025-03 three_pointers/text_frames", 
                         font_size=51, font_type="ExtraBold", 
                         font_color=(255, 255, 255), font_outline_width=3, 
                         font_outline_color=(0, 0, 0), line_spacing_factor=2.0):
    """
    Reads f_top_shooters.csv and generates frames displaying:
    - Season
    - Total 3PM
    - Record (highest Total 3PM seen up until that frame)
    
    Frames are saved as .png images in the specified directory.
    """
    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Load data
    df_top_shooters = pd.read_csv(file_path)

    # Rename column for clarity
    df_top_shooters.rename(columns={"3p_cum": "three_point_cum"}, inplace=True)

    # Ensure required columns exist
    required_cols = {"season", "three_point_cum"}
    if not required_cols.issubset(df_top_shooters.columns):
        print(f"Error: The file must contain {required_cols} columns.")
        return

    # Load Montserrat font
    font_path = os.path.join("..", "Montserrat", f"Montserrat-{font_type}.ttf")
    try:
        font = ImageFont.truetype(font_path, font_size)
    except IOError:
        print(f"Montserrat font {font_type} not found. Using default font.")
        font = ImageFont.load_default()

    # Sort data from last to first ranked player
    df_top_shooters.sort_values(["rank", "season"], ascending=[False, True], inplace=True)

    record_3p = 0  # Track highest Total 3PM seen so far
    frame_index = 1

    # Iterate through the data and generate images
    for _, row in df_top_shooters.iterrows():
        season = row["season"]
        total_3pm = row["three_point_cum"]  # Extract cumulative 3-pointers
        
        # Update record if new value is highest seen so far
        record_3p = max(record_3p, total_3pm)

        # Create an empty image with transparent background
        img = Image.new("RGBA", (width, height), color=(0, 0, 0, 0))
        draw = ImageDraw.Draw(img)

        # Define text values
        text_lines = [
            f"Season: {season}",
            f"Total 3PM: {total_3pm}",
            f"Record: {record_3p}"
        ]

        # Calculate line spacing
        line_height = font_size * line_spacing_factor

        # Position text at the top left with padding
        x_position = 40  # Left-aligned
        y_position = 40  # Start at the top with some padding

        # Draw each line with spacing
        for text in text_lines:
            # Draw text outline
            for dx in range(-font_outline_width, font_outline_width + 1):
                for dy in range(-font_outline_width, font_outline_width + 1):
                    if dx != 0 or dy != 0:
                        draw.text((x_position + dx, y_position + dy), text, font=font, fill=font_outline_color)

            # Draw main text
            draw.text((x_position, y_position), text, font=font, fill=font_color)

            # Move down for the next line
            y_position += line_height

        # Construct the filename
        file_name = f"{frame_index:06d}.png"
        file_path = os.path.join(output_dir, file_name)

        # Save the image
        img.save(file_path, "PNG")
        print(f"✅ Saved frame for Season {season} → {file_name}")

        # Increment frame index
        frame_index += 1

    print(f"✅ Text frames saved in: {output_dir}")

# Run the function
generate_text_frames()
# Out:
# ✅ Saved frame for Season 1 → 000001.png
# ✅ Saved frame for Season 2 → 000002.png
# ✅ Saved frame for Season 3 → 000003.png
# ✅ Saved frame for Season 4 → 000004.png
# ✅ Saved frame for Season 5 → 000005.png
# ✅ Saved frame for Season 6 → 000006.png
# ✅ Saved frame for Season 7 → 000007.png
# ✅ Saved frame for Season 8 → 000008.png
# ✅ Saved frame for Season 9 → 000009.png
# ✅ Saved frame for Season 10 → 000010.png
# ✅ Saved frame for Season 11 → 000011.png
# ✅ Saved frame for Season 12 → 000012.png
# ✅ Saved frame for Season 1 → 000013.png
# ✅ Saved frame for Season 2 → 000014.png
# ✅ Saved frame for Season 3 → 000015.png
# ✅ Saved frame for Season 4 → 000016.png
# ✅ Saved frame for Season 5 → 000017.png
# ✅ Saved frame for Season 6 → 000018.png
# ✅ Saved frame for Season 7 → 000019.png
# ✅ Saved frame for Season 8 → 000020.png
# ✅ Saved frame for Season 9 → 000021.png
# ✅ Saved frame for Season 10 → 000022.png
# ✅ Saved frame for Season 11 → 000023.png
# ✅ Saved frame for Season 12 → 000024.png
# ✅ Saved frame for Season 13 → 000025.png
# ✅ Saved frame for Season 14 → 000026.png
# ✅ Saved frame for Season 15 → 000027.png
# ✅ Saved frame for Season 16 → 000028.png
# ✅ Saved frame for Season 17 → 000029.png
# ✅ Saved frame for Season 18 → 000030.png
# ✅ Saved frame for Season 19 → 000031.png
# ✅ Saved frame for Season 20 → 000032.png
# ✅ Saved frame for Season 1 → 000033.png
# ✅ Saved frame for Season 2 → 000034.png
# ✅ Saved frame for Season 3 → 000035.png
# ✅ Saved frame for Season 4 → 000036.png
# ✅ Saved frame for Season 5 → 000037.png
# ✅ Saved frame for Season 6 → 000038.png
# ✅ Saved frame for Season 7 → 000039.png
# ✅ Saved frame for Season 8 → 000040.png
# ✅ Saved frame for Season 9 → 000041.png
# ✅ Saved frame for Season 10 → 000042.png
# ✅ Saved frame for Season 11 → 000043.png
# ✅ Saved frame for Season 12 → 000044.png
# ✅ Saved frame for Season 13 → 000045.png
# ✅ Saved frame for Season 14 → 000046.png
# ✅ Saved frame for Season 15 → 000047.png
# ✅ Saved frame for Season 16 → 000048.png
# ✅ Saved frame for Season 17 → 000049.png
# ✅ Saved frame for Season 1 → 000050.png
# ✅ Saved frame for Season 2 → 000051.png
# ✅ Saved frame for Season 3 → 000052.png
# ✅ Saved frame for Season 4 → 000053.png
# ✅ Saved frame for Season 5 → 000054.png
# ✅ Saved frame for Season 6 → 000055.png
# ✅ Saved frame for Season 7 → 000056.png
# ✅ Saved frame for Season 8 → 000057.png
# ✅ Saved frame for Season 9 → 000058.png
# ✅ Saved frame for Season 10 → 000059.png
# ✅ Saved frame for Season 11 → 000060.png
# ✅ Saved frame for Season 12 → 000061.png
# ✅ Saved frame for Season 13 → 000062.png
# ✅ Saved frame for Season 14 → 000063.png
# ✅ Saved frame for Season 15 → 000064.png
# ✅ Saved frame for Season 16 → 000065.png
# ✅ Saved frame for Season 17 → 000066.png
# ✅ Saved frame for Season 18 → 000067.png
# ✅ Saved frame for Season 19 → 000068.png
# ✅ Saved frame for Season 20 → 000069.png
# ✅ Saved frame for Season 1 → 000070.png
# ✅ Saved frame for Season 2 → 000071.png
# ✅ Saved frame for Season 3 → 000072.png
# ✅ Saved frame for Season 4 → 000073.png
# ✅ Saved frame for Season 5 → 000074.png
# ✅ Saved frame for Season 6 → 000075.png
# ✅ Saved frame for Season 7 → 000076.png
# ✅ Saved frame for Season 8 → 000077.png
# ✅ Saved frame for Season 9 → 000078.png
# ✅ Saved frame for Season 10 → 000079.png
# ✅ Saved frame for Season 11 → 000080.png
# ✅ Saved frame for Season 12 → 000081.png
# ✅ Saved frame for Season 13 → 000082.png
# ✅ Saved frame for Season 14 → 000083.png
# ✅ Saved frame for Season 15 → 000084.png
# ✅ Saved frame for Season 1 → 000085.png
# ✅ Saved frame for Season 2 → 000086.png
# ✅ Saved frame for Season 3 → 000087.png
# ✅ Saved frame for Season 4 → 000088.png
# ✅ Saved frame for Season 5 → 000089.png
# ✅ Saved frame for Season 6 → 000090.png
# ✅ Saved frame for Season 7 → 000091.png
# ✅ Saved frame for Season 8 → 000092.png
# ✅ Saved frame for Season 9 → 000093.png
# ✅ Saved frame for Season 10 → 000094.png
# ✅ Saved frame for Season 11 → 000095.png
# ✅ Saved frame for Season 12 → 000096.png
# ✅ Saved frame for Season 13 → 000097.png
# ✅ Saved frame for Season 14 → 000098.png
# ✅ Saved frame for Season 1 → 000099.png
# ✅ Saved frame for Season 2 → 000100.png
# ✅ Saved frame for Season 3 → 000101.png
# ✅ Saved frame for Season 4 → 000102.png
# ✅ Saved frame for Season 5 → 000103.png
# ✅ Saved frame for Season 6 → 000104.png
# ✅ Saved frame for Season 7 → 000105.png
# ✅ Saved frame for Season 8 → 000106.png
# ✅ Saved frame for Season 9 → 000107.png
# ✅ Saved frame for Season 10 → 000108.png
# ✅ Saved frame for Season 11 → 000109.png
# ✅ Saved frame for Season 12 → 000110.png
# ✅ Saved frame for Season 13 → 000111.png
# ✅ Saved frame for Season 14 → 000112.png
# ✅ Saved frame for Season 15 → 000113.png
# ✅ Saved frame for Season 16 → 000114.png
# ✅ Saved frame for Season 17 → 000115.png
# ✅ Saved frame for Season 18 → 000116.png
# ✅ Saved frame for Season 1 → 000117.png
# ✅ Saved frame for Season 2 → 000118.png
# ✅ Saved frame for Season 3 → 000119.png
# ✅ Saved frame for Season 4 → 000120.png
# ✅ Saved frame for Season 5 → 000121.png
# ✅ Saved frame for Season 6 → 000122.png
# ✅ Saved frame for Season 7 → 000123.png
# ✅ Saved frame for Season 8 → 000124.png
# ✅ Saved frame for Season 9 → 000125.png
# ✅ Saved frame for Season 10 → 000126.png
# ✅ Saved frame for Season 11 → 000127.png
# ✅ Saved frame for Season 12 → 000128.png
# ✅ Saved frame for Season 13 → 000129.png
# ✅ Saved frame for Season 14 → 000130.png
# ✅ Saved frame for Season 15 → 000131.png
# ✅ Saved frame for Season 16 → 000132.png
# ✅ Saved frame for Season 1 → 000133.png
# ✅ Saved frame for Season 2 → 000134.png
# ✅ Saved frame for Season 3 → 000135.png
# ✅ Saved frame for Season 4 → 000136.png
# ✅ Saved frame for Season 5 → 000137.png
# ✅ Saved frame for Season 6 → 000138.png
# ✅ Saved frame for Season 7 → 000139.png
# ✅ Saved frame for Season 8 → 000140.png
# ✅ Saved frame for Season 9 → 000141.png
# ✅ Saved frame for Season 10 → 000142.png
# ✅ Saved frame for Season 11 → 000143.png
# ✅ Saved frame for Season 12 → 000144.png
# ✅ Saved frame for Season 13 → 000145.png
# ✅ Saved frame for Season 14 → 000146.png
# ✅ Saved frame for Season 15 → 000147.png
# ✅ Saved frame for Season 1 → 000148.png
# ✅ Saved frame for Season 2 → 000149.png
# ✅ Saved frame for Season 3 → 000150.png
# ✅ Saved frame for Season 4 → 000151.png
# ✅ Saved frame for Season 5 → 000152.png
# ✅ Saved frame for Season 6 → 000153.png
# ✅ Saved frame for Season 7 → 000154.png
# ✅ Saved frame for Season 8 → 000155.png
# ✅ Saved frame for Season 9 → 000156.png
# ✅ Saved frame for Season 10 → 000157.png
# ✅ Saved frame for Season 11 → 000158.png
# ✅ Saved frame for Season 12 → 000159.png
# ✅ Saved frame for Season 1 → 000160.png
# ✅ Saved frame for Season 2 → 000161.png
# ✅ Saved frame for Season 3 → 000162.png
# ✅ Saved frame for Season 4 → 000163.png
# ✅ Saved frame for Season 5 → 000164.png
# ✅ Saved frame for Season 6 → 000165.png
# ✅ Saved frame for Season 7 → 000166.png
# ✅ Saved frame for Season 8 → 000167.png
# ✅ Saved frame for Season 9 → 000168.png
# ✅ Saved frame for Season 10 → 000169.png
# ✅ Saved frame for Season 11 → 000170.png
# ✅ Saved frame for Season 12 → 000171.png
# ✅ Saved frame for Season 13 → 000172.png
# ✅ Saved frame for Season 14 → 000173.png
# ✅ Saved frame for Season 15 → 000174.png
# ✅ Saved frame for Season 16 → 000175.png
# ✅ Saved frame for Season 17 → 000176.png
# ✅ Saved frame for Season 18 → 000177.png
# ✅ Saved frame for Season 1 → 000178.png
# ✅ Saved frame for Season 2 → 000179.png
# ✅ Saved frame for Season 3 → 000180.png
# ✅ Saved frame for Season 4 → 000181.png
# ✅ Saved frame for Season 5 → 000182.png
# ✅ Saved frame for Season 6 → 000183.png
# ✅ Saved frame for Season 7 → 000184.png
# ✅ Saved frame for Season 8 → 000185.png
# ✅ Saved frame for Season 9 → 000186.png
# ✅ Saved frame for Season 10 → 000187.png
# ✅ Saved frame for Season 11 → 000188.png
# ✅ Saved frame for Season 12 → 000189.png
# ✅ Saved frame for Season 13 → 000190.png
# ✅ Saved frame for Season 14 → 000191.png
# ✅ Saved frame for Season 15 → 000192.png
# ✅ Saved frame for Season 16 → 000193.png
# ✅ Saved frame for Season 17 → 000194.png
# ✅ Saved frame for Season 18 → 000195.png
# ✅ Saved frame for Season 19 → 000196.png
# ✅ Saved frame for Season 20 → 000197.png
# ✅ Saved frame for Season 21 → 000198.png
# ✅ Saved frame for Season 1 → 000199.png
# ✅ Saved frame for Season 2 → 000200.png
# ✅ Saved frame for Season 3 → 000201.png
# ✅ Saved frame for Season 4 → 000202.png
# ✅ Saved frame for Season 5 → 000203.png
# ✅ Saved frame for Season 6 → 000204.png
# ✅ Saved frame for Season 7 → 000205.png
# ✅ Saved frame for Season 8 → 000206.png
# ✅ Saved frame for Season 9 → 000207.png
# ✅ Saved frame for Season 10 → 000208.png
# ✅ Saved frame for Season 11 → 000209.png
# ✅ Saved frame for Season 12 → 000210.png
# ✅ Saved frame for Season 13 → 000211.png
# ✅ Saved frame for Season 14 → 000212.png
# ✅ Saved frame for Season 15 → 000213.png
# ✅ Saved frame for Season 16 → 000214.png
# ✅ Saved frame for Season 17 → 000215.png
# ✅ Saved frame for Season 18 → 000216.png
# ✅ Saved frame for Season 19 → 000217.png
# ✅ Saved frame for Season 1 → 000218.png
# ✅ Saved frame for Season 2 → 000219.png
# ✅ Saved frame for Season 3 → 000220.png
# ✅ Saved frame for Season 4 → 000221.png
# ✅ Saved frame for Season 5 → 000222.png
# ✅ Saved frame for Season 6 → 000223.png
# ✅ Saved frame for Season 7 → 000224.png
# ✅ Saved frame for Season 8 → 000225.png
# ✅ Saved frame for Season 9 → 000226.png
# ✅ Saved frame for Season 10 → 000227.png
# ✅ Saved frame for Season 11 → 000228.png
# ✅ Saved frame for Season 12 → 000229.png
# ✅ Saved frame for Season 13 → 000230.png
# ✅ Saved frame for Season 14 → 000231.png
# ✅ Saved frame for Season 15 → 000232.png
# ✅ Saved frame for Season 16 → 000233.png
# ✅ Saved frame for Season 17 → 000234.png
# ✅ Saved frame for Season 1 → 000235.png
# ✅ Saved frame for Season 2 → 000236.png
# ✅ Saved frame for Season 3 → 000237.png
# ✅ Saved frame for Season 4 → 000238.png
# ✅ Saved frame for Season 5 → 000239.png
# ✅ Saved frame for Season 6 → 000240.png
# ✅ Saved frame for Season 7 → 000241.png
# ✅ Saved frame for Season 8 → 000242.png
# ✅ Saved frame for Season 9 → 000243.png
# ✅ Saved frame for Season 1 → 000244.png
# ✅ Saved frame for Season 2 → 000245.png
# ✅ Saved frame for Season 3 → 000246.png
# ✅ Saved frame for Season 4 → 000247.png
# ✅ Saved frame for Season 5 → 000248.png
# ✅ Saved frame for Season 6 → 000249.png
# ✅ Saved frame for Season 7 → 000250.png
# ✅ Saved frame for Season 8 → 000251.png
# ✅ Saved frame for Season 9 → 000252.png
# ✅ Saved frame for Season 10 → 000253.png
# ✅ Saved frame for Season 11 → 000254.png
# ✅ Saved frame for Season 12 → 000255.png
# ✅ Saved frame for Season 13 → 000256.png
# ✅ Saved frame for Season 14 → 000257.png
# ✅ Saved frame for Season 15 → 000258.png
# ✅ Saved frame for Season 16 → 000259.png
# ✅ Saved frame for Season 17 → 000260.png
# ✅ Saved frame for Season 18 → 000261.png
# ✅ Saved frame for Season 19 → 000262.png
# ✅ Saved frame for Season 1 → 000263.png
# ✅ Saved frame for Season 2 → 000264.png
# ✅ Saved frame for Season 3 → 000265.png
# ✅ Saved frame for Season 4 → 000266.png
# ✅ Saved frame for Season 5 → 000267.png
# ✅ Saved frame for Season 6 → 000268.png
# ✅ Saved frame for Season 7 → 000269.png
# ✅ Saved frame for Season 8 → 000270.png
# ✅ Saved frame for Season 9 → 000271.png
# ✅ Saved frame for Season 10 → 000272.png
# ✅ Saved frame for Season 11 → 000273.png
# ✅ Saved frame for Season 12 → 000274.png
# ✅ Saved frame for Season 13 → 000275.png
# ✅ Saved frame for Season 14 → 000276.png
# ✅ Saved frame for Season 15 → 000277.png
# ✅ Saved frame for Season 16 → 000278.png
# ✅ Saved frame for Season 17 → 000279.png
# ✅ Saved frame for Season 1 → 000280.png
# ✅ Saved frame for Season 2 → 000281.png
# ✅ Saved frame for Season 3 → 000282.png
# ✅ Saved frame for Season 4 → 000283.png
# ✅ Saved frame for Season 5 → 000284.png
# ✅ Saved frame for Season 6 → 000285.png
# ✅ Saved frame for Season 7 → 000286.png
# ✅ Saved frame for Season 8 → 000287.png
# ✅ Saved frame for Season 9 → 000288.png
# ✅ Saved frame for Season 10 → 000289.png
# ✅ Saved frame for Season 11 → 000290.png
# ✅ Saved frame for Season 12 → 000291.png
# ✅ Saved frame for Season 13 → 000292.png
# ✅ Saved frame for Season 14 → 000293.png
# ✅ Saved frame for Season 15 → 000294.png
# ✅ Saved frame for Season 16 → 000295.png
# ✅ Saved frame for Season 17 → 000296.png
# ✅ Saved frame for Season 18 → 000297.png
# ✅ Saved frame for Season 19 → 000298.png
# ✅ Saved frame for Season 1 → 000299.png
# ✅ Saved frame for Season 2 → 000300.png
# ✅ Saved frame for Season 3 → 000301.png
# ✅ Saved frame for Season 4 → 000302.png
# ✅ Saved frame for Season 5 → 000303.png
# ✅ Saved frame for Season 6 → 000304.png
# ✅ Saved frame for Season 7 → 000305.png
# ✅ Saved frame for Season 8 → 000306.png
# ✅ Saved frame for Season 9 → 000307.png
# ✅ Saved frame for Season 10 → 000308.png
# ✅ Saved frame for Season 11 → 000309.png
# ✅ Saved frame for Season 12 → 000310.png
# ✅ Saved frame for Season 13 → 000311.png
# ✅ Saved frame for Season 14 → 000312.png
# ✅ Saved frame for Season 15 → 000313.png
# ✅ Saved frame for Season 16 → 000314.png
# ✅ Saved frame for Season 17 → 000315.png
# ✅ Saved frame for Season 18 → 000316.png
# ✅ Saved frame for Season 19 → 000317.png
# ✅ Saved frame for Season 20 → 000318.png
# ✅ Saved frame for Season 1 → 000319.png
# ✅ Saved frame for Season 2 → 000320.png
# ✅ Saved frame for Season 3 → 000321.png
# ✅ Saved frame for Season 4 → 000322.png
# ✅ Saved frame for Season 5 → 000323.png
# ✅ Saved frame for Season 6 → 000324.png
# ✅ Saved frame for Season 7 → 000325.png
# ✅ Saved frame for Season 8 → 000326.png
# ✅ Saved frame for Season 9 → 000327.png
# ✅ Saved frame for Season 10 → 000328.png
# ✅ Saved frame for Season 11 → 000329.png
# ✅ Saved frame for Season 12 → 000330.png
# ✅ Saved frame for Season 13 → 000331.png
# ✅ Saved frame for Season 14 → 000332.png
# ✅ Saved frame for Season 15 → 000333.png
# ✅ Saved frame for Season 16 → 000334.png
# ✅ Saved frame for Season 17 → 000335.png
# ✅ Saved frame for Season 18 → 000336.png
# ✅ Saved frame for Season 19 → 000337.png
# ✅ Saved frame for Season 1 → 000338.png
# ✅ Saved frame for Season 2 → 000339.png
# ✅ Saved frame for Season 3 → 000340.png
# ✅ Saved frame for Season 4 → 000341.png
# ✅ Saved frame for Season 5 → 000342.png
# ✅ Saved frame for Season 6 → 000343.png
# ✅ Saved frame for Season 7 → 000344.png
# ✅ Saved frame for Season 8 → 000345.png
# ✅ Saved frame for Season 9 → 000346.png
# ✅ Saved frame for Season 10 → 000347.png
# ✅ Saved frame for Season 11 → 000348.png
# ✅ Saved frame for Season 12 → 000349.png
# ✅ Saved frame for Season 13 → 000350.png
# ✅ Saved frame for Season 14 → 000351.png
# ✅ Saved frame for Season 15 → 000352.png
# ✅ Saved frame for Season 16 → 000353.png
# ✅ Saved frame for Season 17 → 000354.png
# ✅ Saved frame for Season 18 → 000355.png
# ✅ Saved frame for Season 19 → 000356.png
# ✅ Saved frame for Season 20 → 000357.png
# ✅ Saved frame for Season 21 → 000358.png
# ✅ Saved frame for Season 22 → 000359.png
# ✅ Saved frame for Season 1 → 000360.png
# ✅ Saved frame for Season 2 → 000361.png
# ✅ Saved frame for Season 3 → 000362.png
# ✅ Saved frame for Season 4 → 000363.png
# ✅ Saved frame for Season 5 → 000364.png
# ✅ Saved frame for Season 6 → 000365.png
# ✅ Saved frame for Season 7 → 000366.png
# ✅ Saved frame for Season 8 → 000367.png
# ✅ Saved frame for Season 9 → 000368.png
# ✅ Saved frame for Season 10 → 000369.png
# ✅ Saved frame for Season 11 → 000370.png
# ✅ Saved frame for Season 12 → 000371.png
# ✅ Saved frame for Season 13 → 000372.png
# ✅ Saved frame for Season 14 → 000373.png
# ✅ Saved frame for Season 15 → 000374.png
# ✅ Saved frame for Season 1 → 000375.png
# ✅ Saved frame for Season 2 → 000376.png
# ✅ Saved frame for Season 3 → 000377.png
# ✅ Saved frame for Season 4 → 000378.png
# ✅ Saved frame for Season 5 → 000379.png
# ✅ Saved frame for Season 6 → 000380.png
# ✅ Saved frame for Season 7 → 000381.png
# ✅ Saved frame for Season 8 → 000382.png
# ✅ Saved frame for Season 9 → 000383.png
# ✅ Saved frame for Season 10 → 000384.png
# ✅ Saved frame for Season 11 → 000385.png
# ✅ Saved frame for Season 12 → 000386.png
# ✅ Saved frame for Season 13 → 000387.png
# ✅ Saved frame for Season 14 → 000388.png
# ✅ Saved frame for Season 15 → 000389.png
# ✅ Saved frame for Season 16 → 000390.png
# ✅ Saved frame for Season 17 → 000391.png
# ✅ Saved frame for Season 1 → 000392.png
# ✅ Saved frame for Season 2 → 000393.png
# ✅ Saved frame for Season 3 → 000394.png
# ✅ Saved frame for Season 4 → 000395.png
# ✅ Saved frame for Season 5 → 000396.png
# ✅ Saved frame for Season 6 → 000397.png
# ✅ Saved frame for Season 7 → 000398.png
# ✅ Saved frame for Season 8 → 000399.png
# ✅ Saved frame for Season 9 → 000400.png
# ✅ Saved frame for Season 10 → 000401.png
# ✅ Saved frame for Season 11 → 000402.png
# ✅ Saved frame for Season 12 → 000403.png
# ✅ Saved frame for Season 13 → 000404.png
# ✅ Saved frame for Season 14 → 000405.png
# ✅ Saved frame for Season 15 → 000406.png
# ✅ Saved frame for Season 16 → 000407.png
# ✅ Saved frame for Season 17 → 000408.png
# ✅ Saved frame for Season 18 → 000409.png
# ✅ Saved frame for Season 19 → 000410.png
# ✅ Saved frame for Season 20 → 000411.png
# ✅ Saved frame for Season 21 → 000412.png
# ✅ Saved frame for Season 22 → 000413.png
# ✅ Saved frame for Season 1 → 000414.png
# ✅ Saved frame for Season 2 → 000415.png
# ✅ Saved frame for Season 3 → 000416.png
# ✅ Saved frame for Season 4 → 000417.png
# ✅ Saved frame for Season 5 → 000418.png
# ✅ Saved frame for Season 6 → 000419.png
# ✅ Saved frame for Season 7 → 000420.png
# ✅ Saved frame for Season 8 → 000421.png
# ✅ Saved frame for Season 9 → 000422.png
# ✅ Saved frame for Season 10 → 000423.png
# ✅ Saved frame for Season 11 → 000424.png
# ✅ Saved frame for Season 12 → 000425.png
# ✅ Saved frame for Season 13 → 000426.png
# ✅ Saved frame for Season 14 → 000427.png
# ✅ Saved frame for Season 15 → 000428.png
# ✅ Saved frame for Season 16 → 000429.png
# ✅ Saved frame for Season 17 → 000430.png
# ✅ Saved frame for Season 18 → 000431.png
# ✅ Saved frame for Season 1 → 000432.png
# ✅ Saved frame for Season 2 → 000433.png
# ✅ Saved frame for Season 3 → 000434.png
# ✅ Saved frame for Season 4 → 000435.png
# ✅ Saved frame for Season 5 → 000436.png
# ✅ Saved frame for Season 6 → 000437.png
# ✅ Saved frame for Season 7 → 000438.png
# ✅ Saved frame for Season 8 → 000439.png
# ✅ Saved frame for Season 9 → 000440.png
# ✅ Saved frame for Season 10 → 000441.png
# ✅ Saved frame for Season 11 → 000442.png
# ✅ Saved frame for Season 12 → 000443.png
# ✅ Saved frame for Season 1 → 000444.png
# ✅ Saved frame for Season 2 → 000445.png
# ✅ Saved frame for Season 3 → 000446.png
# ✅ Saved frame for Season 4 → 000447.png
# ✅ Saved frame for Season 5 → 000448.png
# ✅ Saved frame for Season 6 → 000449.png
# ✅ Saved frame for Season 7 → 000450.png
# ✅ Saved frame for Season 8 → 000451.png
# ✅ Saved frame for Season 9 → 000452.png
# ✅ Saved frame for Season 10 → 000453.png
# ✅ Saved frame for Season 11 → 000454.png
# ✅ Saved frame for Season 12 → 000455.png
# ✅ Saved frame for Season 13 → 000456.png
# ✅ Saved frame for Season 1 → 000457.png
# ✅ Saved frame for Season 2 → 000458.png
# ✅ Saved frame for Season 3 → 000459.png
# ✅ Saved frame for Season 4 → 000460.png
# ✅ Saved frame for Season 5 → 000461.png
# ✅ Saved frame for Season 6 → 000462.png
# ✅ Saved frame for Season 7 → 000463.png
# ✅ Saved frame for Season 8 → 000464.png
# ✅ Saved frame for Season 9 → 000465.png
# ✅ Saved frame for Season 10 → 000466.png
# ✅ Saved frame for Season 11 → 000467.png
# ✅ Saved frame for Season 12 → 000468.png
# ✅ Saved frame for Season 13 → 000469.png
# ✅ Saved frame for Season 14 → 000470.png
# ✅ Saved frame for Season 15 → 000471.png
# ✅ Saved frame for Season 16 → 000472.png
# ✅ Saved frame for Season 17 → 000473.png
# ✅ Saved frame for Season 18 → 000474.png
# ✅ Saved frame for Season 1 → 000475.png
# ✅ Saved frame for Season 2 → 000476.png
# ✅ Saved frame for Season 3 → 000477.png
# ✅ Saved frame for Season 4 → 000478.png
# ✅ Saved frame for Season 5 → 000479.png
# ✅ Saved frame for Season 6 → 000480.png
# ✅ Saved frame for Season 7 → 000481.png
# ✅ Saved frame for Season 8 → 000482.png
# ✅ Saved frame for Season 9 → 000483.png
# ✅ Saved frame for Season 10 → 000484.png
# ✅ Saved frame for Season 11 → 000485.png
# ✅ Saved frame for Season 12 → 000486.png
# ✅ Saved frame for Season 13 → 000487.png
# ✅ Saved frame for Season 14 → 000488.png
# ✅ Saved frame for Season 15 → 000489.png
# ✅ Saved frame for Season 16 → 000490.png
# ✅ Saved frame for Season 1 → 000491.png
# ✅ Saved frame for Season 2 → 000492.png
# ✅ Saved frame for Season 3 → 000493.png
# ✅ Saved frame for Season 4 → 000494.png
# ✅ Saved frame for Season 5 → 000495.png
# ✅ Saved frame for Season 6 → 000496.png
# ✅ Saved frame for Season 7 → 000497.png
# ✅ Saved frame for Season 8 → 000498.png
# ✅ Saved frame for Season 9 → 000499.png
# ✅ Saved frame for Season 10 → 000500.png
# ✅ Saved frame for Season 11 → 000501.png
# ✅ Saved frame for Season 12 → 000502.png
# ✅ Saved frame for Season 13 → 000503.png
# ✅ Saved frame for Season 14 → 000504.png
# ✅ Saved frame for Season 15 → 000505.png
# ✅ Saved frame for Season 16 → 000506.png
# ✅ Text frames saved in: /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2025-03 three_pointers/text_frames
