# %% [markdown]
# # data

# %% [markdown]
# ## d_us_tariffs_raw

# %%
import pandas as pd# Define the data as a list of dictionaries

data = [
    # File 1
    {"country_name": "China", "tariff_charge": 67, "tariff_reciprocal": 34},
    {"country_name": "European Union", "tariff_charge": 39, "tariff_reciprocal": 20},
    {"country_name": "Vietnam", "tariff_charge": 90, "tariff_reciprocal": 46},
    {"country_name": "Taiwan", "tariff_charge": 64, "tariff_reciprocal": 32},
    {"country_name": "Japan", "tariff_charge": 46, "tariff_reciprocal": 24},
    {"country_name": "India", "tariff_charge": 52, "tariff_reciprocal": 26},
    {"country_name": "South Korea", "tariff_charge": 50, "tariff_reciprocal": 25},
    {"country_name": "Thailand", "tariff_charge": 72, "tariff_reciprocal": 36},
    {"country_name": "Switzerland", "tariff_charge": 61, "tariff_reciprocal": 31},
    {"country_name": "Indonesia", "tariff_charge": 64, "tariff_reciprocal": 32},
    {"country_name": "Malaysia", "tariff_charge": 47, "tariff_reciprocal": 24},
    {"country_name": "Cambodia", "tariff_charge": 97, "tariff_reciprocal": 49},
    {"country_name": "United Kingdom", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "South Africa", "tariff_charge": 60, "tariff_reciprocal": 30},
    {"country_name": "Brazil", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Bangladesh", "tariff_charge": 74, "tariff_reciprocal": 37},
    {"country_name": "Singapore", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Israel", "tariff_charge": 33, "tariff_reciprocal": 17},
    {"country_name": "Philippines", "tariff_charge": 34, "tariff_reciprocal": 17},
    {"country_name": "Chile", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Australia", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Pakistan", "tariff_charge": 58, "tariff_reciprocal": 29},
    {"country_name": "Turkey", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Sri Lanka", "tariff_charge": 88, "tariff_reciprocal": 44},
    {"country_name": "Colombia", "tariff_charge": 10, "tariff_reciprocal": 10},
    
    # File 2
    {"country_name": "Peru", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Nicaragua", "tariff_charge": 36, "tariff_reciprocal": 18},
    {"country_name": "Norway", "tariff_charge": 30, "tariff_reciprocal": 15},
    {"country_name": "Costa Rica", "tariff_charge": 17, "tariff_reciprocal": 10},
    {"country_name": "Jordan", "tariff_charge": 40, "tariff_reciprocal": 20},
    {"country_name": "Dominican Republic", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "United Arab Emirates", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "New Zealand", "tariff_charge": 20, "tariff_reciprocal": 10},
    {"country_name": "Argentina", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Ecuador", "tariff_charge": 12, "tariff_reciprocal": 10},
    {"country_name": "Guatemala", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Honduras", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Madagascar", "tariff_charge": 93, "tariff_reciprocal": 47},
    {"country_name": "Myanmar", "tariff_charge": 88, "tariff_reciprocal": 44},
    {"country_name": "Tunisia", "tariff_charge": 55, "tariff_reciprocal": 28},
    {"country_name": "Kazakhstan", "tariff_charge": 54, "tariff_reciprocal": 27},
    {"country_name": "Serbia", "tariff_charge": 74, "tariff_reciprocal": 37},
    {"country_name": "Egypt", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Saudi Arabia", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "El Salvador", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Côte d'Ivoire", "tariff_charge": 41, "tariff_reciprocal": 21},
    {"country_name": "Laos", "tariff_charge": 95, "tariff_reciprocal": 48},
    {"country_name": "Botswana", "tariff_charge": 74, "tariff_reciprocal": 37},
    {"country_name": "Trinidad and Tobago", "tariff_charge": 12, "tariff_reciprocal": 10},
    {"country_name": "Morocco", "tariff_charge": 10, "tariff_reciprocal": 10},

    # File 3
    {"country_name": "Algeria", "tariff_charge": 59, "tariff_reciprocal": 30},
    {"country_name": "Oman", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Uruguay", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Bahamas", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Lesotho", "tariff_charge": 99, "tariff_reciprocal": 50},
    {"country_name": "Ukraine", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Bahrain", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Qatar", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Mauritius", "tariff_charge": 80, "tariff_reciprocal": 40},
    {"country_name": "Fiji", "tariff_charge": 63, "tariff_reciprocal": 32},
    {"country_name": "Iceland", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Kenya", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Liechtenstein", "tariff_charge": 73, "tariff_reciprocal": 37},
    {"country_name": "Guyana", "tariff_charge": 76, "tariff_reciprocal": 38},
    {"country_name": "Haiti", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Bosnia and Herzegovina", "tariff_charge": 70, "tariff_reciprocal": 35},
    {"country_name": "Nigeria", "tariff_charge": 27, "tariff_reciprocal": 14},
    {"country_name": "Namibia", "tariff_charge": 42, "tariff_reciprocal": 21},
    {"country_name": "Brunei", "tariff_charge": 47, "tariff_reciprocal": 24},
    {"country_name": "Bolivia", "tariff_charge": 20, "tariff_reciprocal": 10},
    {"country_name": "Panama", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Venezuela", "tariff_charge": 29, "tariff_reciprocal": 15},
    {"country_name": "North Macedonia", "tariff_charge": 65, "tariff_reciprocal": 33},
    {"country_name": "Ethiopia", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Ghana", "tariff_charge": 17, "tariff_reciprocal": 10},

    # File 4
    {"country_name": "Moldova", "tariff_charge": 61, "tariff_reciprocal": 31},
    {"country_name": "Angola", "tariff_charge": 63, "tariff_reciprocal": 32},
    {"country_name": "DR Congo", "tariff_charge": 22, "tariff_reciprocal": 11},
    {"country_name": "Jamaica", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Mozambique", "tariff_charge": 31, "tariff_reciprocal": 16},
    {"country_name": "Paraguay", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Zambia", "tariff_charge": 33, "tariff_reciprocal": 17},
    {"country_name": "Lebanon", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Tanzania", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Iraq", "tariff_charge": 78, "tariff_reciprocal": 39},
    {"country_name": "Georgia", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Senegal", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Azerbaijan", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Cameroon", "tariff_charge": 22, "tariff_reciprocal": 11},
    {"country_name": "Uganda", "tariff_charge": 20, "tariff_reciprocal": 10},
    {"country_name": "Albania", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Armenia", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Nepal", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Sint Maarten", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Falkland Islands", "tariff_charge": 82, "tariff_reciprocal": 41},
    {"country_name": "Gabon", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Kuwait", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Togo", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Suriname", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Belize", "tariff_charge": 10, "tariff_reciprocal": 10},

    # File 5 (First Section)
    {"country_name": "Papua New Guinea", "tariff_charge": 15, "tariff_reciprocal": 10},
    {"country_name": "Malawi", "tariff_charge": 34, "tariff_reciprocal": 17},
    {"country_name": "Liberia", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "British Virgin Islands", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Afghanistan", "tariff_charge": 49, "tariff_reciprocal": 10},
    {"country_name": "Zimbabwe", "tariff_charge": 35, "tariff_reciprocal": 18},
    {"country_name": "Benin", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Barbados", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Monaco", "tariff_charge": 10, "tariff_reciprocal": 41},
    {"country_name": "Syria", "tariff_charge": 81, "tariff_reciprocal": 10},
    {"country_name": "Uzbekistan", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Congo", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Djibouti", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "French Polynesia", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Cayman Islands", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Kosovo", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Curaçao", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Vanuatu", "tariff_charge": 44, "tariff_reciprocal": 22},
    {"country_name": "Rwanda", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Sierra Leone", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Mongolia", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "San Marino", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Antigua and Barbuda", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Bermuda", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Eswatini", "tariff_charge": 10, "tariff_reciprocal": 10},

    # File 5 (Second Section)
    {"country_name": "Marshall Islands", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Saint Pierre and Miquelon", "tariff_charge": 99, "tariff_reciprocal": 50},
    {"country_name": "Saint Kitts and Nevis", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Turkmenistan", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Grenada", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Sudan", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Turks and Caicos", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Aruba", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Montenegro", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Saint Helena", "tariff_charge": 15, "tariff_reciprocal": 10},
    {"country_name": "Kyrgyzstan", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Yemen", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Saint Vincent and the Grenadines", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Niger", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Saint Lucia", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Nauru", "tariff_charge": 59, "tariff_reciprocal": 30},
    {"country_name": "Equatorial Guinea", "tariff_charge": 25, "tariff_reciprocal": 13},
    {"country_name": "Iran", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Libya", "tariff_charge": 61, "tariff_reciprocal": 31},
    {"country_name": "Samoa", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Guinea", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Timor-Leste", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Montserrat", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Chad", "tariff_charge": 26, "tariff_reciprocal": 13},
    {"country_name": "Mali", "tariff_charge": 10, "tariff_reciprocal": 10},

    # File 6 (First Section)
    {"country_name": "Maldives", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Tajikistan", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Cabo Verde", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Burundi", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Guadeloupe", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Bhutan", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Martinique", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Tonga", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Mauritania", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Dominica", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Micronesia", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Gambia", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "French Guiana", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Christmas Island", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Andorra", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Central African Rep.", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Solomon Islands", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Mayotte", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Anguilla", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Cocos Islands", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Eritrea", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Cook Islands", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "South Sudan", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Comoros", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Kiribati", "tariff_charge": 10, "tariff_reciprocal": 10},

    # File 6 (Second Section)
    {"country_name": "São Tomé and Príncipe", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Norfolk Island", "tariff_charge": 58, "tariff_reciprocal": 29},
    {"country_name": "Gibraltar", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Tuvalu", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "British Indian Ocean Territory", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Tokelau", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Guinea-Bissau", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Svalbard and Jan Mayen", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Heard and McDonald Islands", "tariff_charge": 10, "tariff_reciprocal": 10},
    {"country_name": "Reunion", "tariff_charge": 73, "tariff_reciprocal": 37}
]

pd.DataFrame(data).to_csv('d_us_tariffs_raw.csv', index=False)

# %% [markdown]
# ## d_us_tariffs

# %%
import pandas as pd
from iso3166 import countries

# Load your data
df = pd.read_csv('d_us_tariffs_raw.csv')

# Function to get ISO Alpha-3 code from country name
def get_iso_a3(country_name):
    try:
        # Use the ISO-3166 package to get the country code
        return countries.get(country_name).alpha3
    except KeyError:
        # Handle special cases or unknowns
        country_corrections = {
            "Côte d'Ivoire": "CIV",
            "DR Congo": "COD",
            "Central African Rep.": "CAF",
            "British Virgin Islands": "VGB",
            "Eswatini": "SWZ",
            "São Tomé and Príncipe": "STP",
            "Syria": "SYR",
            "Micronesia": "FSM",
            "Cook Islands": "COK",
            "Turks and Caicos": "TCA",
            "Svalbard and Jan Mayen": "SJM",
            "Guinea-Bissau": "GNB",
            "Heard and McDonald Islands": "HMD",
            "French Polynesia": "PYF",
            "Christmas Island": "CXR",
            "Cocos Islands": "CCK",
            "San Marino": "SMR",
            "Tokelau": "TKL",
            "Montserrat": "MSR",
            "Saint Helena": "SHN",
            "Sint Maarten": "SXM",
            "Falkland Islands": "FLK",
            "Saint Pierre and Miquelon": "SPM",
            "British Indian Ocean Territory": "IOT",
            "Norfolk Island": "NFK",
            "Turkmenistan": "TKM",
            "Gibraltar": "GIB",
            "Guadeloupe": "GLP",
            "Martinique": "MTQ",
            "Reunion": "REU",
            "New Zealand": "NZL",
            "French Guiana": "GUF",
            "Iran": "IRN",
            "Vanuatu": "VUT",
            "Kuwait": "KWT",
            "Aruba": "ABW",
            "Curaçao": "CUW",
            "Monaco": "MCO",
            "Palestine": "PSE",
            "Somalia": "SOM",
            "Western Sahara": "ESH",
            "Greenland": "GRL",
            "Vietnam": "VNM",
            "South Korea": "KOR",
            "United Kingdom": "GBR",
            "Turkey": "TUR",
            "Laos": "LAO",
            "Brunei": "BRN",
            "Bolivia": "BOL",
            "Venezuela": "VEN",
            "Moldova": "MDA",
            "Tanzania": "TZA"
        }
        return country_corrections.get(country_name, None)

# Apply the function to get ISO codes
df['country_code'] = df['country_name'].apply(get_iso_a3)

# Reorder columns to place 'country_code' as the second column
df = df[['country_name', 'country_code', 'tariff_charge', 'tariff_reciprocal']]

# Save the DataFrame to the new file name
df.to_csv('d_us_tariffs.csv', index=False)

# Display the first few rows
df.head()
# Out:
#      country_name country_code  tariff_charge  tariff_reciprocal
# 0           China          CHN             67                 34
# 1  European Union         None             39                 20
# 2         Vietnam          VNM             90                 46
# 3          Taiwan          TWN             64                 32
# 4           Japan          JPN             46                 24

# %%
import pandas as pd

# Load the data
df = pd.read_csv('d_us_tariffs.csv')

# Display rows where 'country_code' is missing (NaN)
missing_codes = df[df['country_code'].isna()]

# Display the result
print(f"Number of countries with missing country_code: {len(missing_codes)}")
missing_codes
# Out:
# Number of countries with missing country_code: 1
#      country_name country_code  tariff_charge  tariff_reciprocal
# 1  European Union          NaN             39                 20

# %%
import pandas as pd
from iso3166 import countries

# Load your CSV file
df = pd.read_csv('d_us_tariffs.csv')

# List of all EU countries and their ISO Alpha-3 codes
eu_countries = {
    "Austria": "AUT", "Belgium": "BEL", "Bulgaria": "BGR", "Croatia": "HRV",
    "Cyprus": "CYP", "Czech Republic": "CZE", "Denmark": "DNK", "Estonia": "EST",
    "Finland": "FIN", "France": "FRA", "Germany": "DEU", "Greece": "GRC",
    "Hungary": "HUN", "Ireland": "IRL", "Italy": "ITA", "Latvia": "LVA",
    "Lithuania": "LTU", "Luxembourg": "LUX", "Malta": "MLT", "Netherlands": "NLD",
    "Poland": "POL", "Portugal": "PRT", "Romania": "ROU", "Slovakia": "SVK",
    "Slovenia": "SVN", "Spain": "ESP", "Sweden": "SWE"
}

# Tariff data from the "European Union" entry
eu_tariff_charge = df.loc[df['country_name'] == 'European Union', 'tariff_charge'].values[0]
eu_tariff_reciprocal = df.loc[df['country_name'] == 'European Union', 'tariff_reciprocal'].values[0]

# Remove the "European Union" row from the DataFrame
df = df[df['country_name'] != 'European Union']

# Add each EU country as a separate row if it doesn't already exist in the DataFrame
existing_countries = df['country_name'].tolist()
new_rows = []

for country, code in eu_countries.items():
    if country not in existing_countries:
        new_rows.append({
            "country_name": country,
            "country_code": code,
            "tariff_charge": eu_tariff_charge,
            "tariff_reciprocal": eu_tariff_reciprocal
        })

# Append the new rows to the DataFrame
df = pd.concat([df, pd.DataFrame(new_rows)], ignore_index=True)

# Save the updated DataFrame to the same CSV file
df.to_csv('d_us_tariffs.csv', index=False)

# # Display the rows of the newly added countries
# print(df.loc[df['country_name'].isin(eu_countries.keys())])

# %%
import pandas as pd

# Load your CSV file
df = pd.read_csv('d_us_tariffs.csv')

# List of ISO Alpha-3 codes for all EU countries
eu_country_codes = [
    "AUT", "BEL", "BGR", "HRV", "CYP", "CZE", "DNK", "EST", "FIN", "FRA", 
    "DEU", "GRC", "HUN", "IRL", "ITA", "LVA", "LTU", "LUX", "MLT", "NLD", 
    "POL", "PRT", "ROU", "SVK", "SVN", "ESP", "SWE"
]

# Add a new column 'is_eu' with True or False based on whether the country is part of the EU
df['is_eu'] = df['country_code'].apply(lambda code: code in eu_country_codes)

# Save the updated DataFrame back to the file
df.to_csv('d_us_tariffs.csv', index=False)

# Display the first few rows to confirm
df.head()
# Out:
#   country_name country_code  tariff_charge  tariff_reciprocal  is_eu
# 0        China          CHN             67                 34  False
# 1      Vietnam          VNM             90                 46  False
# 2       Taiwan          TWN             64                 32  False
# 3        Japan          JPN             46                 24  False
# 4        India          IND             52                 26  False

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('d_us_tariffs.csv')

# Convert all entries in the 'country_code' column to strings and strip whitespace
df['country_code'] = df['country_code'].astype(str).str.strip()

# Filter for rows where 'country_code' is exactly 'N/A'
na_countries = df[df['country_code'] == 'nan']['country_name'].unique()

# Display the distinct countries with 'N/A' as their country code
print("✅ Countries with 'N/A' as their country_code:")
for country in sorted(na_countries):
    print(country)
# Out:
# ✅ Countries with 'N/A' as their country_code:

# %%
import pandas as pd

def tidy_country_codes():
    # Load the existing data
    df = pd.read_csv('d_us_tariffs.csv')

    # ISO A3 codes for countries with N/A codes
    iso_a3_mapping = {
        'Afghanistan': 'AFG', 'Albania': 'ALB', 'American Samoa': 'ASM', 'Andorra': 'AND', 'Anguilla': 'AIA',
        'Antigua and Barbuda': 'ATG', 'Armenia': 'ARM', 'Aruba': 'ABW', 'Azerbaijan': 'AZE', 'Bahamas': 'BHS',
        'Barbados': 'BRB', 'Belize': 'BLZ', 'Benin': 'BEN', 'Bermuda': 'BMU', 'Bhutan': 'BTN', 
        'Bosnia and Herzegovina': 'BIH', 'Botswana': 'BWA', 'Bouvet Island': 'BVT', 
        'British Indian Ocean Territory': 'IOT', 'Brunei Darussalam': 'BRN', 'Cambodia': 'KHM', 
        'Cameroon': 'CMR', 'Cayman Islands': 'CYM', 'Chad': 'TCD', 'Christmas Island': 'CXR', 
        'Cocos (Keeling) Islands': 'CCK', 'Cook Islands': 'COK', 'Curaçao': 'CUW', 'Côte d’Ivoire': 'CIV',
        'Djibouti': 'DJI', 'Dominica': 'DMA', 'Dominican Republic': 'DOM', 'El Salvador': 'SLV', 
        'Eritrea': 'ERI', 'Falkland Islands (Malvinas)': 'FLK', 'Faroe Islands': 'FRO', 
        'Federated States of Micronesia': 'FSM', 'Fiji': 'FJI', 'French Guiana': 'GUF', 
        'French Polynesia': 'PYF', 'French Southern Territories': 'ATF', 'Gambia': 'GMB', 
        'Georgia': 'GEO', 'Gibraltar': 'GIB', 'Greenland': 'GRL', 'Grenada': 'GRD', 
        'Guadeloupe': 'GLP', 'Guam': 'GUM', 'Guyana': 'GUY', 'Haïti': 'HTI', 
        'Heard Island and McDonald Islands': 'HMD', 'Honduras': 'HND', 'Kazakhstan': 'KAZ', 
        'Kiribati': 'KIR', 'Kyrgyzstan': 'KGZ', 'Laos': 'LAO', 'Lebanon': 'LBN', 
        'Liechtenstein': 'LIE', 'Macao': 'MAC', 'Macedonia': 'MKD', 'Madagascar': 'MDG', 
        'Maldives': 'MDV', 'Marshall Islands': 'MHL', 'Martinique': 'MTQ', 'Mauritania': 'MRT', 
        'Mayotte': 'MYT', 'Moldova': 'MDA', 'Monaco': 'MCO', 'Montenegro': 'MNE', 
        'Montserrat': 'MSR', 'Mozambique': 'MOZ', 'Myanmar': 'MMR', 'Namibia': 'NAM', 
        'Nauru': 'NRU', 'Nepal': 'NPL', 'Netherlands Antilles': 'ANT', 'New Caledonia': 'NCL', 
        'Nicaragua': 'NIC', 'Niue': 'NIU', 'Norfolk Island': 'NFK', 'North Korea': 'PRK', 
        'Northern Mariana Islands': 'MNP', 'Palau': 'PLW', 'Palestine': 'PSE', 
        'Papua New Guinea': 'PNG', 'Paraguay': 'PRY', 'Pitcairn': 'PCN', 
        'Republic of South Sudan': 'SSD', 'Reunion': 'REU', 'Saint Helena': 'SHN', 
        'Saint Kitts and Nevis': 'KNA', 'Saint Lucia': 'LCA', 'Saint Martin (Dutch)': 'SXM', 
        'Saint Martin (French)': 'MAF', 'Saint Pierre and Miquelon': 'SPM', 
        'Saint Vincent and the Grenadines': 'VCT', 'Samoa': 'WSM', 'San Marino': 'SMR', 
        'Sao Tome and Principe': 'STP', 'Serbia': 'SRB', 'Seychelles': 'SYC', 
        'Solomon Islands': 'SLB', 'Somalia': 'SOM', 
        'South Georgia and the South Sandwich Islands': 'SGS', 'Sudan': 'SDN', 
        'Suriname': 'SUR', 'Svalbard and Jan Mayen': 'SJM', 'Syrian Arab Republic': 'SYR', 
        'Tajikistan': 'TJK', 'Timor-Leste': 'TLS', 'Tokelau': 'TKL', 'Tonga': 'TON', 
        'Trinidad and Tobago': 'TTO', 'Turkmenistan': 'TKM', 'Turks and Caicos Islands': 'TCA', 
        'Tuvalu': 'TUV', 'United States Minor Outlying Islands': 'UMI', 
        'Uzbekistan': 'UZB', 'Vanuatu': 'VUT', 'Vatican City State': 'VAT', 
        'Virgin Islands (British)': 'VGB', 'Virgin Islands (U.S.)': 'VIR', 
        'Wallis and Futuna': 'WLF', 'Western Sahara': 'ESH', 'Zimbabwe': 'ZWE'
    }

    # Update country codes
    df['country_code'] = df.apply(lambda x: iso_a3_mapping.get(x['country_name'], x['country_code']), axis=1)

    # Save the updated data
    df.to_csv('d_us_tariffs.csv', index=False)
    print("✅ Country codes updated successfully.")

# Run the function
tidy_country_codes()
# Out:
# ✅ Country codes updated successfully.

# %% [markdown]
# ## tidy_country_names

# %%
# import pandas as pd

# # Load the CSV file
# df = pd.read_csv('d_us_tariffs.csv')

# # Get unique country names
# unique_countries = df['country_name'].unique()

# # Display all unique country names sorted alphabetically
# print("Unique country names:")
# for country in sorted(unique_countries):
#     print(country)

# %%
import pandas as pd

def tidy_country_names(csv_path):
    # Define the country name replacements
    replacements = {
        "Democratic People's Republic of Korea": "North Korea",
        "United Republic of Tanzania": "Tanzania",
        "Netherlands (Kingdom of the)": "Netherlands",
        "Venezuela (Bolivarian Republic of)": "Venezuela",
        "Iran (Islamic Republic of)": "Iran",
        "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
        "Bolivia (Plurinational State of)": "Bolivia",
        "Syrian Arab Republic": "Syria",
        "occupied Palestinian territory, including east Jerusalem": "Palestine",
        "Micronesia (Federated States of)": "Micronesia",
        "Democratic Republic of the Congo": "DR Congo",
        "Republic of Korea": "South Korea",
        "Lao People's Democratic Republic": "Lao",
        "Viet Nam": "Vietnam",
        "Russian Federation": "Russia",
        "United States of America": "United States",
        "Republic of Moldova": "Moldova",
        "Saint Vincent and the Grenadines": "St. Vincent & Grenadines",
        "St. Vincent and the Grenadines": "St. Vincent & Grenadines",
        "West Bank and Gaza": "Palestine",
        "Yemen, Rep.": "Yemen",
        "Venezuela, RB": "Venezuela",
        "Micronesia, Fed. Sts.": "Micronesia",
        "Macao SAR, China": "Macao",
        "Lao PDR": "Lao",
        "Kyrgyz Republic": "Kyrgyzstan",
        "Korea, Rep.": "South Korea",
        "Korea, Dem. People's Rep.": "North Korea",
        "Iran, Islamic Rep.": "Iran",
        "Hong Kong SAR, China": "Hong Kong",
        "Gambia, The": "Gambia",
        "Egypt, Arab Rep.": "Egypt",
        "Congo, Rep.": "Congo",
        "Congo, Dem. Rep.": "DR Congo",
        "Bahamas, The": "The Bahamas",
        "St. Martin (French part)": "St. Martin (French)",
        "Sint Maarten (Dutch part)": "St. Martin (Dutch)",
        "Federated States of Micronesia": "Micronesia",
        "Republic of South Sudan": "South Sudan",
        "Democratic Republic Congo": "DR Congo",
        "Turks and Caicos Islands": "Turks and Caicos",
        "Central African Republic": "Central African Rep.",
        "Northern Mariana Islands": "Northern Mariana",
        "Heard and McDonald Islands": "Heard and McDonald"
    }

    # Read CSV
    df = pd.read_csv(csv_path)

    # Replace country names
    df["country_name"] = df["country_name"].replace(replacements)

    # Overwrite CSV
    df.to_csv(csv_path, index=False)

    print(f"✅ Tidied and saved: {csv_path}")

tidy_country_names("d_us_tariffs.csv")
# Out:
# ✅ Tidied and saved: d_us_tariffs.csv

# %%
import pandas as pd

def dedup_csv(input_path="d_us_tariffs.csv", output_path="d_us_tariffs.csv"):
    # Load the dataset
    df = pd.read_csv(input_path)
    
    # Remove duplicate rows
    df_deduped = df.drop_duplicates()
    
    # Save the deduplicated dataset
    df_deduped.to_csv(output_path, index=False)
    
    # Report the number of duplicates removed
    duplicates_removed = len(df) - len(df_deduped)
    print(f"✅ Saved deduplicated file to '{output_path}'.")
    print(f"Number of duplicate rows removed: {duplicates_removed}")

# Run the deduplication function
dedup_csv()
# Out:
# ✅ Saved deduplicated file to 'd_us_tariffs.csv'.
# Number of duplicate rows removed: 0

# %% [markdown]
# ## excluded_territories

# %%
# excluded_territories = {''}

# Territories to exclude
excluded_territories = {
    'Bouvet Island', 'Christmas Island', 'Cocos (Keeling) Islands', 'Heard Island and McDonald Islands',
    'Pitcairn', 'South Georgia and the South Sandwich Islands', 'Svalbard and Jan Mayen', 'French Southern Territories',
    'American Samoa', 'Anguilla', 'Aruba', 'Bermuda', 'British Indian Ocean Territory', 'Cayman Islands',
    'Cook Islands', 'Curaçao', 'Falkland Islands (Malvinas)', 'Faroe Islands', 'French Guiana', 'French Polynesia',
    'Gibraltar', 'Guadeloupe', 'Guam', 'Hong Kong', 'Macao', 'Martinique', 'Mayotte', 'Montserrat',
    'Netherlands Antilles', 'New Caledonia', 'Niue', 'Norfolk Island', 'Northern Mariana Islands', 'Puerto Rico',
    'Reunion', 'Saint Barthelemy', 'Saint Helena', 'Saint Martin (Dutch)', 'Saint Martin (French)', 
    'Saint Pierre and Miquelon', 'Tokelau', 'Turks and Caicos Islands', 'United States Minor Outlying Islands',
    'Virgin Islands (British)', 'Virgin Islands (U.S.)', 'Wallis and Futuna', 'Vatican City State',

    'British Virgin Islands', 'British Indian Ocean Territory', 'Cayman Islands', 'Heard and McDonald', 'Falkland Islands',
    'Cocos Islands'
}

# %% [markdown]
# ## filter_csv

# %%
import pandas as pd
from typing import Union, List, Set

def filter_csv(
    input_path: str = "d_us_tariffs.csv",
    output_path: str = "d_us_tariffs.csv",
    excluded_territories: Union[Set[str], None] = None,
) -> None:
    """
    Filters a CSV file by excluding specified territories, optionally filtering by year(s), and only keeping countries.

    Parameters:
        input_path (str): Path to the input CSV file.
        output_path (str): Path to save the filtered CSV file.
        years (Union[int, List[int], None]): Year(s) to filter by. Can be a single year, list of years, or None.
        excluded_territories (Union[Set[str], None]): A set of territories to exclude. If None, uses default territories.
        only_countries (bool): If True, keeps only rows where 'is_country' is True.

    Returns:
        None
    """
    # Default territories to exclude if not provided
    default_excluded_territories = {
    }

    if excluded_territories is None:
        excluded_territories = default_excluded_territories

    # Load dataset
    df = pd.read_csv(input_path)

    # Filter out excluded territories
    df = df[~df['country_name'].isin(excluded_territories)]


    # Save filtered dataset
    df.to_csv(output_path, index=False)
    print(f"✅ Saved {output_path} successfully.")

# Example usage
filter_csv(excluded_territories=excluded_territories)
# Out:
# ✅ Saved d_us_tariffs.csv successfully.

# %%
import pandas as pd

# Load your CSV file
df = pd.read_csv('d_us_tariffs.csv')

# Create a DataFrame with Mexico and Canada entries
new_rows = pd.DataFrame([
    {"country_name": "Mexico", "country_code": "MEX", "tariff_charge": None, "tariff_reciprocal": 5, "is_eu": False},
    {"country_name": "Canada", "country_code": "CAN", "tariff_charge": None, "tariff_reciprocal": 4, "is_eu": False}
])

# Append the new rows to the original DataFrame
df = pd.concat([df, new_rows], ignore_index=True)

# Save the updated DataFrame back to the file
df.to_csv('d_us_tariffs.csv', index=False)

# Display the last few rows to confirm
print(df.tail())
# Out:
#     country_name country_code tariff_charge  tariff_reciprocal  is_eu
# 183     Slovenia          SVN            39                 20   True
# 184        Spain          ESP            39                 20   True
# 185       Sweden          SWE            39                 20   True
# 186       Mexico          MEX          None                  5  False
# 187       Canada          CAN          None                  4  False

# %% [markdown]
# ## order_csv

# %%
import pandas as pd

def order_csv(csv_path):
    # Read the CSV
    df = pd.read_csv(csv_path)
    
    # Ensure the 'is_eu' column is treated as boolean (if it's saved as text)
    if df['is_eu'].dtype != bool:
        df['is_eu'] = df['is_eu'].astype(bool)
    
    # Sort the DataFrame by 'tariff_reciprocal', 'is_eu' (descending), and 'country_name'
    df_sorted = df.sort_values(by=['tariff_reciprocal', 'is_eu', 'country_name'], ascending=[True, False, True])

    # Save back to the same file
    df_sorted.to_csv(csv_path, index=False)

    print(f"✅ Sorted by 'tariff_reciprocal', 'is_eu', 'country_name' and saved: {csv_path}")

# Run the function with your file
order_csv('d_us_tariffs.csv')
# Out:
# ✅ Sorted by 'tariff_reciprocal', 'is_eu', 'country_name' and saved: d_us_tariffs.csv

# %% [markdown]
# ## load_world_geojson

# %%
import geopandas as gpd
import requests

def load_world_geojson(source='local'):
    """
    Load world map from a local simplified GeoJSON or a simplified online version.

    Parameters:
        source (str): 'local' or 'web'

    Returns:
        GeoDataFrame or dict: GeoDataFrame if local, dict if web
    """
    if source == 'local':
        local_geojson_path = "../ne_10m_admin_0_countries_lakes/world_simplified.geojson"
        try:
            print(f"📁 Loading local simplified GeoJSON from: {local_geojson_path}")
            return gpd.read_file(local_geojson_path)
        except FileNotFoundError:
            raise FileNotFoundError(f"❌ GeoJSON file not found at: {local_geojson_path}")

    elif source == 'web':
        print("🌍 Loading simplified GeoJSON from Johan's GitHub...")
        geojson_url = "https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json"
        response = requests.get(geojson_url)
        response.raise_for_status()
        return response.json()

    else:
        raise ValueError("Invalid source. Use 'local' or 'web'.")

world_geojson = load_world_geojson('web')
# Out:
# 🌍 Loading simplified GeoJSON from Johan's GitHub...

# %% [markdown]
# # visualise

# %% [markdown]
# ## small_country_coords

# %%
small_countries_coords = {
    'ABW': (12.5, -69.97),     # Aruba
    'AND': (42.5, 1.5),        # Andorra
    'ASM': (-14.3, -170.7),    # American Samoa
    'ATG': (17.1, -61.8),      # Antigua and Barbuda
    'BHR': (26.0, 50.5),       # Bahrain
    'BHS': (25.03, -77.4),     # The Bahamas
    'BMU': (32.3, -64.8),      # Bermuda
    'BRB': (13.1, -59.6),      # Barbados
    #'CHI': (49.5, -2.5),       # Channel Islands (approx. between Jersey and Guernsey)
    'COK': (-21.2, -159.8),    # Cook Islands
    'COM': (-11.6, 43.3),      # Comoros
    'CPV': (15.1, -23.6),      # Cape Verde
    'CUW': (12.2, -69.0),      # Curaçao
    'CYP': (35.1, 33.4),       # Cyprus
    'DJI': (11.8, 42.6),       # Djibouti
    'DMA': (15.4, -61.4),      # Dominica
    'FJI': (-17.7134, 178.065), # Fiji (Suva approx.)
    'FRO': (62.0, -6.79),      # Faroe Islands
    'FSM': (6.9, 158.2),       # Micronesia (Federated States of)
    'GIB': (36.1, -5.35),      # Gibraltar
    'GMB': (13.5, -15.5),      # Gambia
    'GNQ': (1.6, 10.5),        # Equatorial Guinea
    'GNB': (11.8, -15.2),      # Guinea-Bissau
    'GUM': (13.44, 144.79),    # Guam
    'HKG': (22.3, 114.2),      # Hong Kong
    'IMN': (54.2, -4.55),      # Isle of Man
    'JAM': (18.1, -77.3),      # Jamaica
    'KIR': (1.87, 173.0),      # Kiribati
    'KNA': (17.3, -62.7),      # Saint Kitts and Nevis
    'KWT': (29.3759, 47.9774), # Kuwait (Kuwait City approx.)
    'LCA': (13.9, -60.98),     # Saint Lucia
    'LUX': (49.8, 6.1),        # Luxembourg
    'MAC': (22.2, 113.6),      # Macao
    'MAF': (18.07, -63.05),    # St Martin (French)
    'MDV': (3.2, 73.2),        # Maldives
    'MLT': (35.9, 14.5),       # Malta
    'MHL': (7.1, 171.0),       # Marshall Islands
    'MCO': (43.7333, 7.4200),  # Monaco
    'MUS': (-20.2, 57.5),      # Mauritius
    'NCL': (-22.27, 166.44),   # New Caledonia
    'NIU': (-19.05, -169.86),  # Niue
    'NRU': (-0.52, 166.93),    # Nauru
    'OMN': (21.5, 55.9),       # Oman
    'PLW': (7.5, 134.5),       # Palau
    'PRI': (18.2, -66.5),      # Puerto Rico
    'PYF': (-17.6797, -149.4068),  # French Polynesia (Tahiti approx.)
    'QAT': (25.3, 51.5),       # Qatar
    'SGP': (1.35, 103.8),      # Singapore
    'SLB': (-9.6, 160.2),      # Solomon Islands
    'SMR': (43.9333, 12.45),   # San Marino
    'STP': (0.2, 6.6),         # Sao Tome and Principe
    'SYC': (-4.6, 55.5),       # Seychelles
    'SXM': (18.04, -63.07),    # St Martin (Dutch)
    'TKL': (-9.2, -171.8),     # Tokelau
    'TON': (-21.2, -175.2),    # Tonga
    'TCA': (21.8, -72.1),      # Turks and Caicos Islands
    'TUV': (-7.1, 179.2),      # Tuvalu
    'VCT': (13.25, -61.2),     # Saint Vincent and the Grenadines
    'VGB': (18.4, -64.6),      # British Virgin Islands
    'VIR': (18.34, -64.89),    # US Virgin Islands
    'VUT': (-16.0, 167.0),     # Vanuatu
    'WSM': (-13.8, -172.1),    # Samoa
}

# %% [markdown]
# ## color_schemes

# %%
# Define color schemes as a dictionary
color_schemes = {
    "blue": {
        "color_5": "143,217,251",
        "color_25": "96,179,244",
        "color_50": "48,140,238",
        "color_75": "24,72,196",
        "color_95": "17,17,132"
    },
    "red": {
        "color_5": "255,255,153",
        "color_25": "255,217,128",
        "color_50": "255,165,0",
        "color_75": "255,82,0",
        "color_95": "204,0,0"
    },
    "green": {
        "color_5": "204,255,204",
        "color_25": "153,230,153",
        "color_50": "102,204,102",
        "color_75": "0,128,0",
        "color_95": "0,100,0"
    },
    "forest": {
        "color_5": "139,69,19",
        "color_25": "195,176,145",
        "color_50": "150,200,150",
        "color_75": "0,150,0",
        "color_95": "0,100,0"
    },
        "purple": {
            "color_5": "240,210,240",
            "color_25": "215,140,215",
            "color_50": "170,75,170",
            "color_75": "130,20,130",
            "color_95": "55,0,95"
        }

}

# %%
def show_color_schemes(schemes=None):
    import matplotlib.pyplot as plt

    if schemes is None:
        schemes = color_schemes.keys()
    elif isinstance(schemes, str):
        schemes = [schemes]

    selected_schemes = {k: v for k, v in color_schemes.items() if k in schemes}

    fig, axes = plt.subplots(nrows=len(selected_schemes), figsize=(6, 2 * len(selected_schemes)))
    if len(selected_schemes) == 1:
        axes = [axes]  # Ensure axes is iterable

    for ax, (name, scheme) in zip(axes, selected_schemes.items()):
        colors = [tuple(map(int, c.split(','))) for c in scheme.values()]
        colors = [[(r / 255, g / 255, b / 255) for r, g, b in colors]]

        ax.imshow(colors, aspect='auto')
        ax.set_title(f'{name.capitalize()} scheme', fontsize=14, pad=10)
        ax.axis('off')

    plt.tight_layout()
    plt.show()

# Example usage
show_color_schemes(['red'])

# %% [markdown]
# ## map_frames

# %%
import pandas as pd
import plotly.graph_objects as go
import os
import shutil

def map_frames(
    csv_filename,
    world_geojson,
    small_countries_coords,
    color_scheme,
    metric='obesity_rate',
    plot_height=1080,
    plot_width=1920,
    marker_size=10,
    marker_border=3.5,
    parent_folder='2023-03_obesity',
    output_folder='frames_world',
    clear=True,
    canada_color='255,255,224',
    mexico_color='255,255,224',
    us_color='10, 49, 97'  # Default: Blue
):
    try:
        df = pd.read_csv(csv_filename)
    except FileNotFoundError:
        raise FileNotFoundError(f"CSV file '{csv_filename}' not found. Please check the path.")

    if metric not in df.columns:
        raise ValueError(f"Metric '{metric}' not found in the provided CSV file. Available columns: {list(df.columns)}")
    
    try:
        color_5 = color_scheme['color_5']
        color_25 = color_scheme['color_25']
        color_50 = color_scheme['color_50']
        color_75 = color_scheme['color_75']
        color_95 = color_scheme['color_95']
    except KeyError:
        raise ValueError("The color scheme must contain 'color_5', 'color_25', 'color_50', 'color_75', and 'color_95' keys.")

    output_path = f"/Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/{parent_folder}/{output_folder}"
    if clear and os.path.exists(output_path):
        shutil.rmtree(output_path)
    os.makedirs(output_path, exist_ok=True)
    
    colorscale = [
        [0.0, f'rgb({color_5})'],
        [0.25, f'rgb({color_25})'],
        [0.5, f'rgb({color_50})'],
        [0.75, f'rgb({color_75})'],
        [1.0, f'rgb({color_95})']
    ]

    for i in range(1, len(df) + 1):
        df_partial = df.iloc[:i].copy()
        df_partial.loc[:, 'row_index'] = df_partial.index

        fig = go.Figure()

        # Plot the main map
        fig.add_trace(go.Choropleth(
            geojson=world_geojson,
            locations=df_partial['country_code'],
            z=df_partial[metric],
            locationmode='ISO-3',
            colorscale=colorscale,
            marker_line_color='white',
            marker_line_width=1.5,
            zmin=df[metric].min(),
            zmax=df[metric].max(),
            colorbar_title=metric.replace("_", " ").capitalize()
        ))

        # Plot small countries
        small_countries = pd.DataFrame([
            {'country_code': code, 'lat': lat, 'lon': lon}
            for code, (lat, lon) in small_countries_coords.items()
        ])
        
        small_data = small_countries.merge(
            df_partial[['country_code', metric, 'row_index']],
            on='country_code',
            how='left'
        ).dropna(subset=[metric]).sort_values(by='row_index', ascending=True)

        fig.add_trace(go.Scattergeo(
            lon=small_data['lon'],
            lat=small_data['lat'],
            mode='markers',
            marker=dict(
                size=marker_size,
                color=small_data[metric],
                colorscale=colorscale,
                cmin=df[metric].min(),
                cmax=df[metric].max(),
                line=dict(width=marker_border, color='white')
            ),
            hoverinfo='skip',
            showlegend=False
        ))

        # Highlight Canada
        if 'CAN' in df_partial['country_code'].values:
            fig.add_trace(go.Choropleth(
                geojson=world_geojson,
                locations=['CAN'],
                z=[df_partial.loc[df_partial['country_code'] == 'CAN', metric].values[0]],
                locationmode='ISO-3',
                colorscale=[[0, f'rgb({canada_color})'], [1, f'rgb({canada_color})']],
                marker_line_color='white',
                marker_line_width=1.5,
                showlegend=False
            ))

        # Highlight Mexico
        if 'MEX' in df_partial['country_code'].values:
            fig.add_trace(go.Choropleth(
                geojson=world_geojson,
                locations=['MEX'],
                z=[df_partial.loc[df_partial['country_code'] == 'MEX', metric].values[0]],
                locationmode='ISO-3',
                colorscale=[[0, f'rgb({mexico_color})'], [1, f'rgb({mexico_color})']],
                marker_line_color='white',
                marker_line_width=1.5,
                showlegend=False
            ))
        
        # Highlight the United States
        fig.add_trace(go.Choropleth(
            geojson=world_geojson,
            locations=['USA'],
            z=[0],  # Placeholder value since it's not in your CSV
            locationmode='ISO-3',
            colorscale=[[0, f'rgb({us_color})'], [1, f'rgb({us_color})']],
            marker_line_color='white',
            marker_line_width=1.5,
            showlegend=False
        ))

        fig.update_geos(
            showcountries=True,
            countrycolor="white",
            showframe=False,
            showcoastlines=False,
            showlakes=False,
            bgcolor='rgba(0,0,0,0)',
            lataxis_range=[-60, 90],
            projection_rotation={"lon": 40}
        )

        fig.update_layout(
            margin={"r": 0, "t": 0, "l": 0, "b": 0},
            paper_bgcolor='rgba(0,0,0,0)',
            plot_bgcolor='rgba(0,0,0,0)',
            height=plot_height,
            width=plot_width
        )

        filepath = f"{output_path}/{i:04d}.png"
        fig.write_image(filepath, scale=1)

        current_country = df_partial.iloc[-1]['country_name']
        print(f"✅ Saved {filepath} – added: {current_country}")

# %%
color_boundaries = map_frames(
    csv_filename="d_us_tariffs.csv",
    world_geojson=world_geojson,
    small_countries_coords=small_countries_coords,
    color_scheme=color_schemes["red"],
    metric="tariff_reciprocal",
    plot_height=1080,
    plot_width=1920,
    marker_size=23,
    marker_border=2,
    parent_folder="2023-03_tariff",
    output_folder="frames_map",
    clear=True
)
# Out:
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_map/0001.png – added: Canada
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_map/0002.png – added: Mexico
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_map/0003.png – added: Afghanistan
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_map/0004.png – added: Albania
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_map/0005.png – added: Andorra
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_map/0006.png – added: Antigua and Barbuda
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_map/0007.png – added: Argentina
# ✅ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_map/0008.png – added: Armenia
# ...

# %% [markdown]
# ## text_frames

# %%
from PIL import Image, ImageDraw, ImageFont
import pandas as pd
import os
import shutil

def interpolate_color(val, zmin, zmax, rgb_colors):
    if val <= zmin:
        return rgb_colors[0]
    elif val >= zmax:
        return rgb_colors[-1]

    ratio = (val - zmin) / (zmax - zmin)
    if ratio <= 0.25:
        lower_color, upper_color = rgb_colors[0], rgb_colors[1]
        ratio = ratio / 0.25
    elif ratio <= 0.5:
        lower_color, upper_color = rgb_colors[1], rgb_colors[2]
        ratio = (ratio - 0.25) / 0.25
    elif ratio <= 0.75:
        lower_color, upper_color = rgb_colors[2], rgb_colors[3]
        ratio = (ratio - 0.5) / 0.25
    else:
        lower_color, upper_color = rgb_colors[3], rgb_colors[4]
        ratio = (ratio - 0.75) / 0.25

    interpolated_color = tuple([
        int(lower_color[j] + ratio * (upper_color[j] - lower_color[j]))
        for j in range(3)
    ])
    
    return interpolated_color

def text_frames(
    csv_filename,
    color_scheme,
    parent_folder='2023-03_forest',
    output_folder='frames_text',
    output_folder_suffix='',
    metric='forest_area',
    font_type='ExtraBold',
    font_size=100,
    image_width=1920,
    image_height=1080,
    append_percent=False,
    clear=True,
    canada_color='255,255,224',    # Same as in map_frames
    mexico_color='255,255,224',    # Same as in map_frames
    us_color='10,49,97'            # Same as in map_frames
):
    df = pd.read_csv(csv_filename)
    
    # Use the same zmin and zmax as in map_frames
    zmin = df[metric].min()
    zmax = df[metric].max()
    
    color_5 = color_scheme['color_5']
    color_25 = color_scheme['color_25']
    color_50 = color_scheme['color_50']
    color_75 = color_scheme['color_75']
    color_95 = color_scheme['color_95']

    rgb_colors = [
        tuple(map(int, color_5.split(','))),
        tuple(map(int, color_25.split(','))),
        tuple(map(int, color_50.split(','))),
        tuple(map(int, color_75.split(','))),
        tuple(map(int, color_95.split(',')))
    ]

    full_output_folder = os.path.join(parent_folder, output_folder + output_folder_suffix)
    base_output_path = os.path.join(
        "/Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics",
        full_output_folder
    )
    
    if clear and os.path.exists(base_output_path):
        shutil.rmtree(base_output_path)
    os.makedirs(base_output_path, exist_ok=True)

    text_types = ['title', 'value', 'rank', 'country']
    text_paths = {text_type: os.path.join(base_output_path, text_type) for text_type in text_types}
    for path in text_paths.values():
        os.makedirs(path, exist_ok=True)

    df['rank'] = df[metric].rank(method='min', ascending=False).astype(int)

    font_path = os.path.join("..", "..", "Montserrat", f"Montserrat-{font_type}.ttf")
    try:
        font = ImageFont.truetype(font_path, font_size)
    except IOError:
        print(f"Montserrat font '{font_type}' not found. Using default font.")
        font = ImageFont.load_default()

    for i in range(1, len(df) + 1):
        row = df.iloc[i - 1]
        country = row['country_name']
        rate_numeric = row[metric]
        rank = row['rank']
        
        if append_percent:
            rate_formatted = f"{row[metric]:,.1f}%"
        else:
            rate_formatted = f"{row[metric]:,.1f}"

        # Assigning special colors for Canada, Mexico, and the US
        if country == "Canada":
            text_color = tuple(map(int, canada_color.split(',')))
        elif country == "Mexico":
            text_color = tuple(map(int, mexico_color.split(',')))
        elif country == "United States":
            text_color = tuple(map(int, us_color.split(',')))
        else:
            text_color = interpolate_color(rate_numeric, zmin, zmax, rgb_colors)

        outline_color = (255, 255, 255)

        texts = {
            'title': "TARIFF",
            'value': rate_formatted,
            'rank': f"#{rank}",
            'country': country.upper()
        }

        x = 100
        y_positions = {
            'title': 100,
            'value': 250,
            'rank': 400,
            'country': 550
        }

        for text_type, text in texts.items():
            y = y_positions[text_type]
            filepath = os.path.join(text_paths[text_type], f"{i:04d}.png")
            save_text_component(text, text_color, outline_color, font, image_width, image_height, x, y, filepath)

# %%
text_frames(
    csv_filename="d_us_tariffs.csv",
    color_scheme=color_schemes["red"],
    parent_folder="2023-03_tariff",
    output_folder="frames_text",
    metric="tariff_reciprocal",
    font_type="ExtraBold",
    font_size=100,
    image_width=1920,
    image_height=1080,
    append_percent=True,
    clear=True,
    canada_color="255,255,224",  # Very white yellow for Canada
    mexico_color="255,255,224",  # Very white yellow for Mexico
    us_color="10,49,97"          # Dark blue for the US
)
# Out:
# 💬 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_text/title/0001.png
# 💬 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_text/value/0001.png
# 💬 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_text/rank/0001.png
# 💬 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_text/country/0001.png
# 💬 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_text/title/0002.png
# 💬 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_text/value/0002.png
# 💬 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_text/rank/0002.png
# 💬 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_text/country/0002.png
# ...

# %% [markdown]
# ## flag_frames

# %%
import pandas as pd
import os
import shutil
import requests
from PIL import Image
from io import BytesIO
from pycountry import countries

def flag_frames(
    csv_filename,
    parent_folder='2023-03_obesity',
    output_folder='frames_flag',
    image_width=1920,
    image_height=1080,
    flag_height=540,  # Desired height for all flags (half of 1080 for consistency)
    clear=True
):
    output_path = os.path.join(
        "/Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics",
        parent_folder,
        output_folder
    )

    if clear and os.path.exists(output_path):
        shutil.rmtree(output_path)
    os.makedirs(output_path, exist_ok=True)

    # Load data and preserve original order
    df = pd.read_csv(csv_filename)
    
    # Create ISO-3 to ISO-2 mapping
    iso_map = {c.alpha_3: c.alpha_2.lower() for c in countries if hasattr(c, 'alpha_3')}
    
    # Add Kosovo manually
    iso_map['XKX'] = 'xk'  # Kosovo's unofficial ISO-2 code used by many systems

    for i in range(len(df)):
        row = df.iloc[i]
        code3 = row['country_code']
        country = row['country_name']
        code2 = iso_map.get(code3)

        if not code2:
            print(f"⚠️ No ISO-2 code for {country} ({code3})")
            continue

        url = f"https://flagcdn.com/w320/{code2}.png"
        try:
            response = requests.get(url)
            response.raise_for_status()
            flag = Image.open(BytesIO(response.content)).convert("RGBA")
        except Exception as e:
            print(f"❌ Failed to load flag for {country} ({code3}): {e}")
            continue

        # Resize the flag to the desired height, maintaining aspect ratio
        flag_aspect = flag.width / flag.height
        target_width = int(flag_height * flag_aspect)
        flag = flag.resize((target_width, flag_height), Image.LANCZOS)

        # Create a blank transparent image
        img = Image.new("RGBA", (image_width, image_height), (0, 0, 0, 0))

        # Calculate position for right alignment
        x = image_width - flag.width  # Right-aligned
        y = (image_height - flag.height) // 2  # Vertically centered

        # Paste the flag onto the transparent background
        img.paste(flag, (x, y), flag)

        filepath = os.path.join(output_path, f"{i+1:04d}.png")
        img.save(filepath)
        print(f"🇺🇳 Saved {filepath} – {country}")

# %%
flag_frames(
    csv_filename='d_us_tariffs.csv',
    parent_folder='2023-03_tariff',
    output_folder='frames_flag',
    image_width=1920,
    image_height=1080,
    flag_height=540,
    clear=True
)
# Out:
# 🇺🇳 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_flag/0001.png – Canada
# 🇺🇳 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_flag/0002.png – Mexico
# 🇺🇳 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_flag/0003.png – Afghanistan
# 🇺🇳 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_flag/0004.png – Albania
# 🇺🇳 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_flag/0005.png – Andorra
# 🇺🇳 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_flag/0006.png – Antigua and Barbuda
# 🇺🇳 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_flag/0007.png – Argentina
# 🇺🇳 Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_tariff/frames_flag/0008.png – Armenia
# ...

# %% [markdown]
# ## history_frames

# %%
# def history_map_frames(
#     csv_filename,
#     world_geojson,
#     small_countries_coords,
#     color_scheme,
#     excluded_territories,
#     metric='forest_perc',
#     plot_height=1080,
#     plot_width=1920,
#     parent_folder='2023-03_forest',
#     output_folder='frames_history',
#     clear=True,
#     marker_size=23,
#     marker_border=2
# ):
#     import pandas as pd
#     import plotly.graph_objects as go
#     import os
#     import shutil

#     # Load data
#     df = pd.read_csv(csv_filename)

#     # Retrieve all available years, including 2024
#     years = sorted(df["year"].dropna().unique(), reverse=True)

#     # Log available years
#     print(f"📅 Available years: {years}")

#     # Prepare the output directory
#     output_path = f"/Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/{parent_folder}/{output_folder}"
#     if clear and os.path.exists(output_path):
#         shutil.rmtree(output_path)
#     os.makedirs(output_path, exist_ok=True)

#     geojson = world_geojson

#     all_countries = pd.DataFrame({
#         'country_code': [
#             feature.get('id') or feature['properties'].get('iso_a3')
#             for feature in geojson['features']
#         ]
#     })

#     small_countries = pd.DataFrame([
#         {'country_code': code, 'lat': lat, 'lon': lon}
#         for code, (lat, lon) in small_countries_coords.items()
#     ])

#     # Process each year individually
#     for index, year in enumerate(years, start=1):
#         # Filter data for the current year
#         df_year = df[df['year'] == year].reset_index(drop=True)

#         if df_year.empty:
#             print(f"🚫 No data available for year {year}. Skipping...")
#             continue

#         # Exclude territories
#         if excluded_territories:
#             df_year = df_year[~df_year['country_name'].isin(excluded_territories)]

#         # Calculate color boundaries
#         color_boundaries = {
#             "color_5_value": df_year[metric].quantile(0.05),
#             "color_25_value": df_year[metric].quantile(0.25),
#             "color_50_value": df_year[metric].quantile(0.50),
#             "color_75_value": df_year[metric].quantile(0.75),
#             "color_95_value": df_year[metric].quantile(0.95)
#         }

#         # Extract color scheme
#         colorscale = [
#             [0.0, f'rgb({color_scheme["color_5"]})'],
#             [0.25, f'rgb({color_scheme["color_25"]})'],
#             [0.50, f'rgb({color_scheme["color_50"]})'],
#             [0.75, f'rgb({color_scheme["color_75"]})'],
#             [1.0, f'rgb({color_scheme["color_95"]})']
#         ]

#         df_merged = all_countries.merge(
#             df_year[["country_code", "country_name", metric]],
#             on="country_code", how="left"
#         )

#         small_data = small_countries.merge(
#             df_year[["country_code", metric]],
#             on="country_code",
#             how="left"
#         )
#         small_data = small_data[small_data[metric].notna()]

#         fig = go.Figure()

#         # Choropleth
#         fig.add_trace(go.Choropleth(
#             geojson=geojson,
#             locations=df_merged['country_code'],
#             z=df_merged[metric],
#             locationmode='ISO-3',
#             colorscale=colorscale,
#             zmin=color_boundaries["color_5_value"],
#             zmax=color_boundaries["color_95_value"],
#             colorbar_title=metric.replace("_", " ").capitalize(),
#             text=df_merged['country_name'],
#             hoverinfo='location+z+text',
#             marker_line_color='white',
#             marker_line_width=1.5,
#         ))

#         # Small country markers
#         fig.add_trace(go.Scattergeo(
#             lon=small_data['lon'],
#             lat=small_data['lat'],
#             mode='markers',
#             marker=dict(
#                 size=marker_size,
#                 color=small_data[metric],
#                 colorscale=colorscale,
#                 cmin=color_boundaries["color_5_value"],
#                 cmax=color_boundaries["color_95_value"],
#                 colorbar=None,
#                 line=dict(width=marker_border, color='white'),
#                 opacity=1.0
#             ),
#             hoverinfo='skip',
#             showlegend=False
#         ))

#         # Global map layout
#         fig.update_geos(
#             showcountries=True,
#             countrycolor="white",
#             showframe=False,
#             showcoastlines=False,
#             showlakes=False,
#             bgcolor='rgba(0,0,0,0)',
#             lataxis_range=[-60, 90],
#             projection_rotation={"lon": 40}
#         )

#         fig.update_layout(
#             margin={"r": 0, "t": 0, "l": 0, "b": 0},
#             paper_bgcolor='rgba(0,0,0,0)',
#             plot_bgcolor='rgba(0,0,0,0)',
#             height=plot_height,
#             width=plot_width,
#             coloraxis_colorbar=dict(
#                 len=0.5,
#                 yanchor='middle',
#                 y=0.5
#             )
#         )

#         filepath = f"{output_path}/{index:04d}.png"
#         fig.write_image(filepath, scale=1)
#         print(f"✅ Saved {filepath} for year {year}")

# %%
history_map_frames(
    csv_filename="d_women_labour.csv",
    world_geojson=world_geojson,
    small_countries_coords=small_countries_coords,
    color_scheme=color_schemes["purple"],  # Use the specific color scheme
    excluded_territories=excluded_territories,
    metric="women_perc",
    plot_height=1080,
    plot_width=1920,
    parent_folder="2023-03_women_labour",
    output_folder="frames_history_map",
    clear=True,
    marker_size=23,
    marker_border=2  # New parameter to control marker border thickness
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 history_map_frames(
#       2     csv_filename="d_women_labour.csv",
#       3     world_geojson=world_geojson,
#       4     small_countries_coords=small_countries_coords,
#       5     color_scheme=color_schemes["purple"],  # Use the specific color scheme
#       6     excluded_territories=excluded_territories,
#       7     metric="women_perc",
#       8     plot_height=1080,
#       9     plot_width=1920,
#      10     parent_folder="2023-03_women_labour",
#      11     output_folder="frames_history_map",
#      12     clear=True,
#      13     marker_size=23,
#      14     marker_border=2  # New parameter to control marker border thickness
#      15 )
#
# NameError: name 'history_map_frames' is not defined

# %% [markdown]
# ## history_year_frames

# %%
# from PIL import Image, ImageDraw, ImageFont
# import pandas as pd
# import os
# import shutil

# def history_year_frames(
#     csv_filename,
#     parent_folder='2023-03_obesity',
#     output_folder='frames_years_only',
#     font_type='ExtraBold',
#     font_size=200,
#     image_width=1920,
#     image_height=1080,
#     alignment='center',
#     clear=True
# ):
    
#     # Colors
#     text_color = (0, 0, 0, 0)  # black (fully opaque)
#     outline_color = (255, 255, 255, 255)  # white (fully opaque)

#     # Output path
#     output_path = os.path.join(
#         "/Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics",
#         parent_folder,
#         output_folder
#     )
#     if clear and os.path.exists(output_path):
#         shutil.rmtree(output_path)
#     os.makedirs(output_path, exist_ok=True)

#     # Load data
#     df = pd.read_csv(csv_filename)

#     # Load font
#     font_path = os.path.join("..", "..", "Montserrat", f"Montserrat-{font_type}.ttf")
#     try:
#         font = ImageFont.truetype(font_path, font_size)
#     except IOError:
#         print(f"Montserrat font '{font_type}' not found. Using default font.")
#         font = ImageFont.load_default()

#     # Unique years (reverse order), excluding 2024
#     years = sorted([year for year in df['year'].unique() if year != 2024], reverse=True)
    
#     for i, year in enumerate(years, start=1):
#         text = str(year)

#         # Create transparent image
#         img = Image.new('RGBA', (image_width, image_height), (0, 0, 0, 0))
#         draw = ImageDraw.Draw(img)

#         bbox = draw.textbbox((0, 0), text, font=font)
#         text_width = bbox[2] - bbox[0]
#         text_height = bbox[3] - bbox[1]

#         if alignment == 'left':
#             x = 100
#         elif alignment == 'right':
#             x = image_width - text_width - 100
#         else:
#             x = (image_width - text_width) / 2

#         y = (image_height - text_height) / 2

#         # Outline
#         offset = 4
#         for dx in [-offset, 0, offset]:
#             for dy in [-offset, 0, offset]:
#                 if dx == 0 and dy == 0:
#                     continue
#                 draw.text((x + dx, y + dy), text, font=font, fill=outline_color)

#         # Main text
#         draw.text((x, y), text, font=font, fill=text_color)

#         filepath = os.path.join(output_path, f"{i:04d}.png")
#         img.save(filepath)
#         print(f"🖼️ Saved {filepath}")

# %%
# history_year_frames(
#     csv_filename='d_women_labour.csv',
#     parent_folder='2023-03_women_labour',
#     output_folder='frames_history_years',
#     font_type='ExtraBold',
#     font_size=200,
#     image_width=1920,
#     image_height=1080,
#     alignment='center',
#     clear=True
#     )
# Out:
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_women_labour/frames_history_years/0001.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_women_labour/frames_history_years/0002.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_women_labour/frames_history_years/0003.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_women_labour/frames_history_years/0004.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_women_labour/frames_history_years/0005.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_women_labour/frames_history_years/0006.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_women_labour/frames_history_years/0007.png
# 🖼️ Saved /Users/arya/Documents/Adobe/Premiere Pro/Horizon Analytics/2023-03_women_labour/frames_history_years/0008.png
# ...
